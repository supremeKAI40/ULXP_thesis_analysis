# %%
import os
import pandas as pd
import re

# %%
import os
import pandas as pd
import re

def extract_period_info(file_path):
    """Extracts mean period and standard deviation from a given file."""
    with open(file_path, 'r') as f:
        content = f.read()
    
    # Debugging output
    print(f"\nReading file: {file_path}")
    print(content[:500])  # Print first 500 characters to verify format

    mean_match = re.search(r"Mean\s+period:\s*([\d\.]+)", content)
    std_match = re.search(r"Standard\s+deviation\s+\(error\s+on\s+period\):\s*([\d\.eE+-]+)", content)

    if mean_match and std_match:
        mean_period = float(mean_match.group(1))
        std_dev = float(std_match.group(1))
        print(f"Extracted -> Mean Period: {mean_period}, Std Dev: {std_dev}")  # Debugging
        return mean_period, std_dev
    else:
        print("Pattern not found in file.")  # Debugging
        return None, None

def process_observations(base_directory):
    """Traverses the bootstrap_500 directory and extracts period data from all ProposalIDs."""
    categories = ['HE', 'ME', 'LE']
    data = {cat: [] for cat in categories}

    for proposal_id in os.listdir(base_directory):
        proposal_path = os.path.join(base_directory, proposal_id)
        if not os.path.isdir(proposal_path) or not proposal_id.startswith("P"):  # Ensure it's a ProposalID folder
            continue

        for obs_id in os.listdir(proposal_path):
            obs_path = os.path.join(proposal_path, obs_id, 'bootstrap_output')
            if not os.path.isdir(obs_path):
                continue

            for category in categories:
                category_dir = os.path.join(obs_path, category)
                if not os.path.isdir(category_dir):
                    continue
                
                for file in os.listdir(category_dir):
                    if file.endswith(".qdp"):
                        file_path = os.path.join(category_dir, file)
                        mean_period, std_dev = extract_period_info(file_path)
                        if mean_period is not None and std_dev is not None:
                            lc_identifier = file.split('_lcnet_')[0]  # Extract LC file identifier
                            data[category].append([lc_identifier, mean_period, std_dev])

    # Save the results to CSV files
    for category in categories:
        if data[category]:  # Only save if there is data
            df = pd.DataFrame(data[category], columns=['LC Identifier', 'Mean Period', 'Std Dev'])
            output_file = f"{base_directory}/{category}_period_data.csv"
            df.to_csv(output_file, index=False)
            print(f"Saved {category} data to {output_file}")
        else:
            print(f"No data found for {category}, CSV not created.")

# %%
# Example usage
base_directory = "bootstrap_500"  # Path where ProposalIDs are stored
process_observations(base_directory)
# Out:
# Reading file: bootstrap_500/P0504279/P0504279001/bootstrap_output/HE/P050427900103_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79503
# Standard deviation (error on period): 2.14336e-05
#
# Extracted -> Mean Period: 9.79503, Std Dev: 2.14336e-05
#
# Reading file: bootstrap_500/P0504279/P0504279001/bootstrap_output/HE/P050427900101_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.7951
# Standard deviation (error on period): 9.15423e-06
#
# Extracted -> Mean Period: 9.7951, Std Dev: 9.15423e-06
#
# Reading file: bootstrap_500/P0504279/P0504279001/bootstrap_output/HE/P050427900102_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79466
# Standard deviation (error on period): 0.000102116
#
# Extracted -> Mean Period: 9.79466, Std Dev: 0.000102116
#
# Reading file: bootstrap_500/P0504279/P0504279001/bootstrap_output/HE/P050427900104_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79501
# Standard deviation (error on period): 9.29516e-06
#
# Extracted -> Mean Period: 9.79501, Std Dev: 9.29516e-06
#
# Reading file: bootstrap_500/P0504279/P0504279001/bootstrap_output/ME/P050427900101_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79509
# Standard deviation (error on period): 2.25122e-05
#
# Extracted -> Mean Period: 9.79509, Std Dev: 2.25122e-05
#
# Reading file: bootstrap_500/P0504279/P0504279001/bootstrap_output/ME/P050427900103_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79504
# Standard deviation (error on period): 2.93223e-05
#
# Extracted -> Mean Period: 9.79504, Std Dev: 2.93223e-05
#
# Reading file: bootstrap_500/P0504279/P0504279001/bootstrap_output/ME/P050427900102_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79508
# Standard deviation (error on period): 3.58162e-05
#
# Extracted -> Mean Period: 9.79508, Std Dev: 3.58162e-05
#
# Reading file: bootstrap_500/P0504279/P0504279001/bootstrap_output/ME/P050427900104_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79504
# Standard deviation (error on period): 2.60423e-05
#
# Extracted -> Mean Period: 9.79504, Std Dev: 2.60423e-05
#
# Reading file: bootstrap_500/P0504279/P0504279001/bootstrap_output/LE/P050427900102_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79503
# Standard deviation (error on period): 4.755e-05
#
# Extracted -> Mean Period: 9.79503, Std Dev: 4.755e-05
#
# Reading file: bootstrap_500/P0504279/P0504279001/bootstrap_output/LE/P050427900101_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79506
# Standard deviation (error on period): 3.35529e-05
#
# Extracted -> Mean Period: 9.79506, Std Dev: 3.35529e-05
#
# Reading file: bootstrap_500/P0504279/P0504279001/bootstrap_output/LE/P050427900104_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79502
# Standard deviation (error on period): 3.26497e-05
#
# Extracted -> Mean Period: 9.79502, Std Dev: 3.26497e-05
#
# Reading file: bootstrap_500/P0504279/P0504279001/bootstrap_output/LE/P050427900103_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79499
# Standard deviation (error on period): 3.97391e-05
#
# Extracted -> Mean Period: 9.79499, Std Dev: 3.97391e-05
#
# Reading file: bootstrap_500/P0504196/P0504196012/bootstrap_output/HE/P050419601201_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79287
# Standard deviation (error on period): 9.28946e-05
#
# Extracted -> Mean Period: 9.79287, Std Dev: 9.28946e-05
#
# Reading file: bootstrap_500/P0504196/P0504196013/bootstrap_output/HE/P050419601301_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79265
# Standard deviation (error on period): 1.76635e-05
#
# Extracted -> Mean Period: 9.79265, Std Dev: 1.76635e-05
#
# Reading file: bootstrap_500/P0504196/P0504196013/bootstrap_output/ME/P050419601301_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79266
# Standard deviation (error on period): 3.74807e-05
#
# Extracted -> Mean Period: 9.79266, Std Dev: 3.74807e-05
#
# Reading file: bootstrap_500/P0504196/P0504196013/bootstrap_output/LE/P050419601301_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79267
# Standard deviation (error on period): 4.52593e-05
#
# Extracted -> Mean Period: 9.79267, Std Dev: 4.52593e-05
#
# Reading file: bootstrap_500/P0504196/P0504196010/bootstrap_output/HE/P050419601001_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79294
# Standard deviation (error on period): 2.64877e-05
#
# Extracted -> Mean Period: 9.79294, Std Dev: 2.64877e-05
#
# Reading file: bootstrap_500/P0504196/P0504196010/bootstrap_output/ME/P050419601001_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79293
# Standard deviation (error on period): 6.16652e-05
#
# Extracted -> Mean Period: 9.79293, Std Dev: 6.16652e-05
#
# Reading file: bootstrap_500/P0504196/P0504196010/bootstrap_output/LE/P050419601001_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79288
# Standard deviation (error on period): 7.47476e-05
#
# Extracted -> Mean Period: 9.79288, Std Dev: 7.47476e-05
#
# Reading file: bootstrap_500/P0504196/P0504196007/bootstrap_output/HE/P050419600703_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79417
# Standard deviation (error on period): 0.000175098
#
# Extracted -> Mean Period: 9.79417, Std Dev: 0.000175098
#
# Reading file: bootstrap_500/P0504196/P0504196007/bootstrap_output/HE/P050419600702_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79328
# Standard deviation (error on period): 3.7081e-05
#
# Extracted -> Mean Period: 9.79328, Std Dev: 3.7081e-05
#
# Reading file: bootstrap_500/P0504196/P0504196007/bootstrap_output/HE/P050419600701_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79348
# Standard deviation (error on period): 0
#
# Extracted -> Mean Period: 9.79348, Std Dev: 0.0
#
# Reading file: bootstrap_500/P0504196/P0504196007/bootstrap_output/ME/P050419600701_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79348
# Standard deviation (error on period): 2.55382e-05
#
# Extracted -> Mean Period: 9.79348, Std Dev: 2.55382e-05
#
# Reading file: bootstrap_500/P0504196/P0504196007/bootstrap_output/ME/P050419600703_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79333
# Standard deviation (error on period): 0.000297944
#
# Extracted -> Mean Period: 9.79333, Std Dev: 0.000297944
#
# Reading file: bootstrap_500/P0504196/P0504196007/bootstrap_output/ME/P050419600702_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79336
# Standard deviation (error on period): 9.89545e-05
#
# Extracted -> Mean Period: 9.79336, Std Dev: 9.89545e-05
#
# Reading file: bootstrap_500/P0504196/P0504196007/bootstrap_output/LE/P050419600702_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79351
# Standard deviation (error on period): 0.000148231
#
# Extracted -> Mean Period: 9.79351, Std Dev: 0.000148231
#
# Reading file: bootstrap_500/P0504196/P0504196007/bootstrap_output/LE/P050419600701_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79344
# Standard deviation (error on period): 3.76696e-05
#
# Extracted -> Mean Period: 9.79344, Std Dev: 3.76696e-05
#
# Reading file: bootstrap_500/P0504196/P0504196007/bootstrap_output/LE/P050419600703_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.78618
# Standard deviation (error on period): 0.00100737
#
# Extracted -> Mean Period: 9.78618, Std Dev: 0.00100737
#
# Reading file: bootstrap_500/P0504196/P0504196006/bootstrap_output/HE/P050419600601_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79373
# Standard deviation (error on period): 1.90158e-05
#
# Extracted -> Mean Period: 9.79373, Std Dev: 1.90158e-05
#
# Reading file: bootstrap_500/P0504196/P0504196006/bootstrap_output/HE/P050419600602_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79339
# Standard deviation (error on period): 0.000246753
#
# Extracted -> Mean Period: 9.79339, Std Dev: 0.000246753
#
# Reading file: bootstrap_500/P0504196/P0504196006/bootstrap_output/HE/P050419600603_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79361
# Standard deviation (error on period): 0.000268145
#
# Extracted -> Mean Period: 9.79361, Std Dev: 0.000268145
#
# Reading file: bootstrap_500/P0504196/P0504196006/bootstrap_output/ME/P050419600601_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79367
# Standard deviation (error on period): 3.4094e-05
#
# Extracted -> Mean Period: 9.79367, Std Dev: 3.4094e-05
#
# Reading file: bootstrap_500/P0504196/P0504196006/bootstrap_output/ME/P050419600602_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79368
# Standard deviation (error on period): 4.98538e-05
#
# Extracted -> Mean Period: 9.79368, Std Dev: 4.98538e-05
#
# Reading file: bootstrap_500/P0504196/P0504196006/bootstrap_output/ME/P050419600603_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.7937
# Standard deviation (error on period): 0.000300403
#
# Extracted -> Mean Period: 9.7937, Std Dev: 0.000300403
#
# Reading file: bootstrap_500/P0504196/P0504196006/bootstrap_output/LE/P050419600603_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.7912
# Standard deviation (error on period): 0.00278952
#
# Extracted -> Mean Period: 9.7912, Std Dev: 0.00278952
#
# Reading file: bootstrap_500/P0504196/P0504196006/bootstrap_output/LE/P050419600601_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79367
# Standard deviation (error on period): 5.61765e-05
#
# Extracted -> Mean Period: 9.79367, Std Dev: 5.61765e-05
#
# Reading file: bootstrap_500/P0504196/P0504196006/bootstrap_output/LE/P050419600602_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.7937
# Standard deviation (error on period): 9.48008e-05
#
# Extracted -> Mean Period: 9.7937, Std Dev: 9.48008e-05
#
# Reading file: bootstrap_500/P0504196/P0504196021/bootstrap_output/HE/P050419602102_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79256
# Standard deviation (error on period): 6.41872e-05
#
# Extracted -> Mean Period: 9.79256, Std Dev: 6.41872e-05
#
# Reading file: bootstrap_500/P0504196/P0504196021/bootstrap_output/HE/P050419602101_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79258
# Standard deviation (error on period): 2.23964e-05
#
# Extracted -> Mean Period: 9.79258, Std Dev: 2.23964e-05
#
# Reading file: bootstrap_500/P0504196/P0504196021/bootstrap_output/ME/P050419602102_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79266
# Standard deviation (error on period): 2.90034e-05
#
# Extracted -> Mean Period: 9.79266, Std Dev: 2.90034e-05
#
# Reading file: bootstrap_500/P0504196/P0504196021/bootstrap_output/ME/P050419602101_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79259
# Standard deviation (error on period): 8.43801e-06
#
# Extracted -> Mean Period: 9.79259, Std Dev: 8.43801e-06
#
# Reading file: bootstrap_500/P0504196/P0504196021/bootstrap_output/LE/P050419602102_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.78909
# Standard deviation (error on period): 0.00310649
#
# Extracted -> Mean Period: 9.78909, Std Dev: 0.00310649
#
# Reading file: bootstrap_500/P0504196/P0504196021/bootstrap_output/LE/P050419602101_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79259
# Standard deviation (error on period): 1.02372e-05
#
# Extracted -> Mean Period: 9.79259, Std Dev: 1.02372e-05
#
# Reading file: bootstrap_500/P0504196/P0504196019/bootstrap_output/HE/P050419601902_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79253
# Standard deviation (error on period): 0.000116542
#
# Extracted -> Mean Period: 9.79253, Std Dev: 0.000116542
#
# Reading file: bootstrap_500/P0504196/P0504196019/bootstrap_output/HE/P050419601903_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79241
# Standard deviation (error on period): 7.32339e-05
#
# Extracted -> Mean Period: 9.79241, Std Dev: 7.32339e-05
#
# Reading file: bootstrap_500/P0504196/P0504196019/bootstrap_output/HE/P050419601901_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79248
# Standard deviation (error on period): 4.13401e-05
#
# Extracted -> Mean Period: 9.79248, Std Dev: 4.13401e-05
#
# Reading file: bootstrap_500/P0504196/P0504196019/bootstrap_output/ME/P050419601903_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79255
# Standard deviation (error on period): 6.87881e-05
#
# Extracted -> Mean Period: 9.79255, Std Dev: 6.87881e-05
#
# Reading file: bootstrap_500/P0504196/P0504196019/bootstrap_output/ME/P050419601902_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79254
# Standard deviation (error on period): 4.22682e-05
#
# Extracted -> Mean Period: 9.79254, Std Dev: 4.22682e-05
#
# Reading file: bootstrap_500/P0504196/P0504196019/bootstrap_output/ME/P050419601901_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.7925
# Standard deviation (error on period): 4.88631e-05
#
# Extracted -> Mean Period: 9.7925, Std Dev: 4.88631e-05
#
# Reading file: bootstrap_500/P0504196/P0504196019/bootstrap_output/LE/P050419601902_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79249
# Standard deviation (error on period): 3.54344e-05
#
# Extracted -> Mean Period: 9.79249, Std Dev: 3.54344e-05
#
# Reading file: bootstrap_500/P0504196/P0504196019/bootstrap_output/LE/P050419601903_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79269
# Standard deviation (error on period): 0.000386696
#
# Extracted -> Mean Period: 9.79269, Std Dev: 0.000386696
#
# Reading file: bootstrap_500/P0504196/P0504196019/bootstrap_output/LE/P050419601901_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.78952
# Standard deviation (error on period): 0.00327386
#
# Extracted -> Mean Period: 9.78952, Std Dev: 0.00327386
#
# Reading file: bootstrap_500/P0504196/P0504196014/bootstrap_output/HE/P050419601402_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.78956
# Standard deviation (error on period): 0.000112942
#
# Extracted -> Mean Period: 9.78956, Std Dev: 0.000112942
#
# Reading file: bootstrap_500/P0504196/P0504196014/bootstrap_output/HE/P050419601403_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79221
# Standard deviation (error on period): 0.000201465
#
# Extracted -> Mean Period: 9.79221, Std Dev: 0.000201465
#
# Reading file: bootstrap_500/P0504196/P0504196014/bootstrap_output/HE/P050419601401_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.78711
# Standard deviation (error on period): 0.000126166
#
# Extracted -> Mean Period: 9.78711, Std Dev: 0.000126166
#
# Reading file: bootstrap_500/P0504196/P0504196014/bootstrap_output/ME/P050419601401_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79238
# Standard deviation (error on period): 0.000875919
#
# Extracted -> Mean Period: 9.79238, Std Dev: 0.000875919
#
# Reading file: bootstrap_500/P0504196/P0504196014/bootstrap_output/ME/P050419601402_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79261
# Standard deviation (error on period): 5.0998e-05
#
# Extracted -> Mean Period: 9.79261, Std Dev: 5.0998e-05
#
# Reading file: bootstrap_500/P0504196/P0504196014/bootstrap_output/ME/P050419601403_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79271
# Standard deviation (error on period): 0.000183859
#
# Extracted -> Mean Period: 9.79271, Std Dev: 0.000183859
#
# Reading file: bootstrap_500/P0504196/P0504196014/bootstrap_output/LE/P050419601403_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79229
# Standard deviation (error on period): 0.000714778
#
# Extracted -> Mean Period: 9.79229, Std Dev: 0.000714778
#
# Reading file: bootstrap_500/P0504196/P0504196014/bootstrap_output/LE/P050419601401_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79059
# Standard deviation (error on period): 0.00271465
#
# Extracted -> Mean Period: 9.79059, Std Dev: 0.00271465
#
# Reading file: bootstrap_500/P0504196/P0504196014/bootstrap_output/LE/P050419601402_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79327
# Standard deviation (error on period): 0.000371466
#
# Extracted -> Mean Period: 9.79327, Std Dev: 0.000371466
#
# Reading file: bootstrap_500/P0504196/P0504196020/bootstrap_output/HE/P050419602002_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79257
# Standard deviation (error on period): 2.02781e-05
#
# Extracted -> Mean Period: 9.79257, Std Dev: 2.02781e-05
#
# Reading file: bootstrap_500/P0504196/P0504196020/bootstrap_output/HE/P050419602001_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.78879
# Standard deviation (error on period): 0.00102601
#
# Extracted -> Mean Period: 9.78879, Std Dev: 0.00102601
#
# Reading file: bootstrap_500/P0504196/P0504196020/bootstrap_output/ME/P050419602001_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79256
# Standard deviation (error on period): 4.11461e-05
#
# Extracted -> Mean Period: 9.79256, Std Dev: 4.11461e-05
#
# Reading file: bootstrap_500/P0504196/P0504196020/bootstrap_output/ME/P050419602002_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79255
# Standard deviation (error on period): 1.54532e-05
#
# Extracted -> Mean Period: 9.79255, Std Dev: 1.54532e-05
#
# Reading file: bootstrap_500/P0504196/P0504196020/bootstrap_output/LE/P050419602001_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79259
# Standard deviation (error on period): 6.18902e-05
#
# Extracted -> Mean Period: 9.79259, Std Dev: 6.18902e-05
#
# Reading file: bootstrap_500/P0504196/P0504196020/bootstrap_output/LE/P050419602002_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79259
# Standard deviation (error on period): 2.15314e-05
#
# Extracted -> Mean Period: 9.79259, Std Dev: 2.15314e-05
#
# Reading file: bootstrap_500/P0504196/P0504196016/bootstrap_output/HE/P050419601601_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79233
# Standard deviation (error on period): 0.000140481
#
# Extracted -> Mean Period: 9.79233, Std Dev: 0.000140481
#
# Reading file: bootstrap_500/P0504196/P0504196016/bootstrap_output/HE/P050419601602_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79249
# Standard deviation (error on period): 0.000202285
#
# Extracted -> Mean Period: 9.79249, Std Dev: 0.000202285
#
# Reading file: bootstrap_500/P0504196/P0504196016/bootstrap_output/HE/P050419601603_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79265
# Standard deviation (error on period): 0.000104038
#
# Extracted -> Mean Period: 9.79265, Std Dev: 0.000104038
#
# Reading file: bootstrap_500/P0504196/P0504196016/bootstrap_output/ME/P050419601603_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79244
# Standard deviation (error on period): 9.04411e-05
#
# Extracted -> Mean Period: 9.79244, Std Dev: 9.04411e-05
#
# Reading file: bootstrap_500/P0504196/P0504196016/bootstrap_output/ME/P050419601602_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79251
# Standard deviation (error on period): 5.2509e-05
#
# Extracted -> Mean Period: 9.79251, Std Dev: 5.2509e-05
#
# Reading file: bootstrap_500/P0504196/P0504196016/bootstrap_output/ME/P050419601601_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79253
# Standard deviation (error on period): 0.000129215
#
# Extracted -> Mean Period: 9.79253, Std Dev: 0.000129215
#
# Reading file: bootstrap_500/P0504196/P0504196016/bootstrap_output/LE/P050419601602_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79247
# Standard deviation (error on period): 9.96755e-05
#
# Extracted -> Mean Period: 9.79247, Std Dev: 9.96755e-05
#
# Reading file: bootstrap_500/P0504196/P0504196016/bootstrap_output/LE/P050419601603_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79275
# Standard deviation (error on period): 0.000441024
#
# Extracted -> Mean Period: 9.79275, Std Dev: 0.000441024
#
# Reading file: bootstrap_500/P0504196/P0504196008/bootstrap_output/HE/P050419600803_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79216
# Standard deviation (error on period): 0.000536832
#
# Extracted -> Mean Period: 9.79216, Std Dev: 0.000536832
#
# Reading file: bootstrap_500/P0504196/P0504196008/bootstrap_output/HE/P050419600802_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79439
# Standard deviation (error on period): 0.00021839
#
# Extracted -> Mean Period: 9.79439, Std Dev: 0.00021839
#
# Reading file: bootstrap_500/P0504196/P0504196008/bootstrap_output/HE/P050419600801_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.7933
# Standard deviation (error on period): 1.66433e-05
#
# Extracted -> Mean Period: 9.7933, Std Dev: 1.66433e-05
#
# Reading file: bootstrap_500/P0504196/P0504196008/bootstrap_output/ME/P050419600802_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79332
# Standard deviation (error on period): 1.97434e-05
#
# Extracted -> Mean Period: 9.79332, Std Dev: 1.97434e-05
#
# Reading file: bootstrap_500/P0504196/P0504196008/bootstrap_output/ME/P050419600803_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79139
# Standard deviation (error on period): 0.00272973
#
# Extracted -> Mean Period: 9.79139, Std Dev: 0.00272973
#
# Reading file: bootstrap_500/P0504196/P0504196008/bootstrap_output/ME/P050419600801_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79333
# Standard deviation (error on period): 2.29608e-05
#
# Extracted -> Mean Period: 9.79333, Std Dev: 2.29608e-05
#
# Reading file: bootstrap_500/P0504196/P0504196008/bootstrap_output/LE/P050419600802_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79326
# Standard deviation (error on period): 7.15765e-05
#
# Extracted -> Mean Period: 9.79326, Std Dev: 7.15765e-05
#
# Reading file: bootstrap_500/P0504196/P0504196008/bootstrap_output/LE/P050419600801_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79324
# Standard deviation (error on period): 0.000103356
#
# Extracted -> Mean Period: 9.79324, Std Dev: 0.000103356
#
# Reading file: bootstrap_500/P0504196/P0504196008/bootstrap_output/LE/P050419600803_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79309
# Standard deviation (error on period): 0.00190723
#
# Extracted -> Mean Period: 9.79309, Std Dev: 0.00190723
#
# Reading file: bootstrap_500/P0504196/P0504196001/bootstrap_output/HE/P050419600101_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79476
# Standard deviation (error on period): 2.29652e-05
#
# Extracted -> Mean Period: 9.79476, Std Dev: 2.29652e-05
#
# Reading file: bootstrap_500/P0504196/P0504196001/bootstrap_output/HE/P050419600103_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79495
# Standard deviation (error on period): 0.000174134
#
# Extracted -> Mean Period: 9.79495, Std Dev: 0.000174134
#
# Reading file: bootstrap_500/P0504196/P0504196001/bootstrap_output/HE/P050419600102_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79491
# Standard deviation (error on period): 5.53191e-05
#
# Extracted -> Mean Period: 9.79491, Std Dev: 5.53191e-05
#
# Reading file: bootstrap_500/P0504196/P0504196001/bootstrap_output/ME/P050419600103_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79481
# Standard deviation (error on period): 0.000187253
#
# Extracted -> Mean Period: 9.79481, Std Dev: 0.000187253
#
# Reading file: bootstrap_500/P0504196/P0504196001/bootstrap_output/ME/P050419600102_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.7947
# Standard deviation (error on period): 7.57601e-05
#
# Extracted -> Mean Period: 9.7947, Std Dev: 7.57601e-05
#
# Reading file: bootstrap_500/P0504196/P0504196001/bootstrap_output/ME/P050419600101_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79483
# Standard deviation (error on period): 1.36967e-05
#
# Extracted -> Mean Period: 9.79483, Std Dev: 1.36967e-05
#
# Reading file: bootstrap_500/P0504196/P0504196001/bootstrap_output/LE/P050419600103_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79434
# Standard deviation (error on period): 0.000318356
#
# Extracted -> Mean Period: 9.79434, Std Dev: 0.000318356
#
# Reading file: bootstrap_500/P0504196/P0504196001/bootstrap_output/LE/P050419600102_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79473
# Standard deviation (error on period): 7.18498e-05
#
# Extracted -> Mean Period: 9.79473, Std Dev: 7.18498e-05
#
# Reading file: bootstrap_500/P0504196/P0504196001/bootstrap_output/LE/P050419600101_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79482
# Standard deviation (error on period): 2.20182e-05
#
# Extracted -> Mean Period: 9.79482, Std Dev: 2.20182e-05
#
# Reading file: bootstrap_500/P0504196/P0504196004/bootstrap_output/HE/P050419600401_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.7941
# Standard deviation (error on period): 0.000114613
#
# Extracted -> Mean Period: 9.7941, Std Dev: 0.000114613
#
# Reading file: bootstrap_500/P0504196/P0504196004/bootstrap_output/HE/P050419600402_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79405
# Standard deviation (error on period): 8.42686e-05
#
# Extracted -> Mean Period: 9.79405, Std Dev: 8.42686e-05
#
# Reading file: bootstrap_500/P0504196/P0504196004/bootstrap_output/HE/P050419600403_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79389
# Standard deviation (error on period): 4.73329e-05
#
# Extracted -> Mean Period: 9.79389, Std Dev: 4.73329e-05
#
# Reading file: bootstrap_500/P0504196/P0504196004/bootstrap_output/ME/P050419600403_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79353
# Standard deviation (error on period): 0.000242184
#
# Extracted -> Mean Period: 9.79353, Std Dev: 0.000242184
#
# Reading file: bootstrap_500/P0504196/P0504196004/bootstrap_output/ME/P050419600401_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79405
# Standard deviation (error on period): 2.13635e-05
#
# Extracted -> Mean Period: 9.79405, Std Dev: 2.13635e-05
#
# Reading file: bootstrap_500/P0504196/P0504196004/bootstrap_output/ME/P050419600402_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.794
# Standard deviation (error on period): 5.94592e-05
#
# Extracted -> Mean Period: 9.794, Std Dev: 5.94592e-05
#
# Reading file: bootstrap_500/P0504196/P0504196004/bootstrap_output/LE/P050419600401_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79405
# Standard deviation (error on period): 8.39607e-05
#
# Extracted -> Mean Period: 9.79405, Std Dev: 8.39607e-05
#
# Reading file: bootstrap_500/P0504196/P0504196004/bootstrap_output/LE/P050419600402_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79407
# Standard deviation (error on period): 4.52504e-05
#
# Extracted -> Mean Period: 9.79407, Std Dev: 4.52504e-05
#
# Reading file: bootstrap_500/P0504196/P0504196004/bootstrap_output/LE/P050419600403_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79356
# Standard deviation (error on period): 0.000265046
#
# Extracted -> Mean Period: 9.79356, Std Dev: 0.000265046
#
# Reading file: bootstrap_500/P0504196/P0504196009/bootstrap_output/HE/P050419600902_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79289
# Standard deviation (error on period): 8.9579e-05
#
# Extracted -> Mean Period: 9.79289, Std Dev: 8.9579e-05
#
# Reading file: bootstrap_500/P0504196/P0504196009/bootstrap_output/HE/P050419600901_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79319
# Standard deviation (error on period): 4.98237e-05
#
# Extracted -> Mean Period: 9.79319, Std Dev: 4.98237e-05
#
# Reading file: bootstrap_500/P0504196/P0504196009/bootstrap_output/HE/P050419600903_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79191
# Standard deviation (error on period): 0.00157582
#
# Extracted -> Mean Period: 9.79191, Std Dev: 0.00157582
#
# Reading file: bootstrap_500/P0504196/P0504196009/bootstrap_output/ME/P050419600903_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79467
# Standard deviation (error on period): 0.000358151
#
# Extracted -> Mean Period: 9.79467, Std Dev: 0.000358151
#
# Reading file: bootstrap_500/P0504196/P0504196009/bootstrap_output/ME/P050419600901_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79309
# Standard deviation (error on period): 6.28204e-05
#
# Extracted -> Mean Period: 9.79309, Std Dev: 6.28204e-05
#
# Reading file: bootstrap_500/P0504196/P0504196009/bootstrap_output/ME/P050419600902_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79288
# Standard deviation (error on period): 7.51532e-05
#
# Extracted -> Mean Period: 9.79288, Std Dev: 7.51532e-05
#
# Reading file: bootstrap_500/P0504196/P0504196009/bootstrap_output/LE/P050419600903_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79102
# Standard deviation (error on period): 0.00196864
#
# Extracted -> Mean Period: 9.79102, Std Dev: 0.00196864
#
# Reading file: bootstrap_500/P0504196/P0504196009/bootstrap_output/LE/P050419600901_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79312
# Standard deviation (error on period): 4.7299e-05
#
# Extracted -> Mean Period: 9.79312, Std Dev: 4.7299e-05
#
# Reading file: bootstrap_500/P0504196/P0504196009/bootstrap_output/LE/P050419600902_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79313
# Standard deviation (error on period): 8.08109e-05
#
# Extracted -> Mean Period: 9.79313, Std Dev: 8.08109e-05
#
# Reading file: bootstrap_500/P0504196/P0504196011/bootstrap_output/HE/P050419601101_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79283
# Standard deviation (error on period): 4.11218e-05
#
# Extracted -> Mean Period: 9.79283, Std Dev: 4.11218e-05
#
# Reading file: bootstrap_500/P0504196/P0504196011/bootstrap_output/ME/P050419601101_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79287
# Standard deviation (error on period): 3.94614e-05
#
# Extracted -> Mean Period: 9.79287, Std Dev: 3.94614e-05
#
# Reading file: bootstrap_500/P0504196/P0504196011/bootstrap_output/LE/P050419601101_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79295
# Standard deviation (error on period): 5.09804e-05
#
# Extracted -> Mean Period: 9.79295, Std Dev: 5.09804e-05
#
# Reading file: bootstrap_500/P0504196/P0504196018/bootstrap_output/HE/P050419601801_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79252
# Standard deviation (error on period): 1.998e-05
#
# Extracted -> Mean Period: 9.79252, Std Dev: 1.998e-05
#
# Reading file: bootstrap_500/P0504196/P0504196018/bootstrap_output/ME/P050419601801_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.7925
# Standard deviation (error on period): 2.40832e-06
#
# Extracted -> Mean Period: 9.7925, Std Dev: 2.40832e-06
#
# Reading file: bootstrap_500/P0504196/P0504196018/bootstrap_output/LE/P050419601801_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79245
# Standard deviation (error on period): 6.83037e-05
#
# Extracted -> Mean Period: 9.79245, Std Dev: 6.83037e-05
#
# Reading file: bootstrap_500/P0504196/P0504196003/bootstrap_output/HE/P050419600303_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79431
# Standard deviation (error on period): 4.89183e-05
#
# Extracted -> Mean Period: 9.79431, Std Dev: 4.89183e-05
#
# Reading file: bootstrap_500/P0504196/P0504196003/bootstrap_output/HE/P050419600302_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79383
# Standard deviation (error on period): 0.000234696
#
# Extracted -> Mean Period: 9.79383, Std Dev: 0.000234696
#
# Reading file: bootstrap_500/P0504196/P0504196003/bootstrap_output/HE/P050419600301_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79445
# Standard deviation (error on period): 2.37823e-05
#
# Extracted -> Mean Period: 9.79445, Std Dev: 2.37823e-05
#
# Reading file: bootstrap_500/P0504196/P0504196003/bootstrap_output/ME/P050419600303_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79432
# Standard deviation (error on period): 7.21859e-05
#
# Extracted -> Mean Period: 9.79432, Std Dev: 7.21859e-05
#
# Reading file: bootstrap_500/P0504196/P0504196003/bootstrap_output/ME/P050419600301_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79434
# Standard deviation (error on period): 2.81247e-05
#
# Extracted -> Mean Period: 9.79434, Std Dev: 2.81247e-05
#
# Reading file: bootstrap_500/P0504196/P0504196003/bootstrap_output/ME/P050419600302_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.7943
# Standard deviation (error on period): 9.70433e-05
#
# Extracted -> Mean Period: 9.7943, Std Dev: 9.70433e-05
#
# Reading file: bootstrap_500/P0504196/P0504196003/bootstrap_output/LE/P050419600302_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79444
# Standard deviation (error on period): 0.000100526
#
# Extracted -> Mean Period: 9.79444, Std Dev: 0.000100526
#
# Reading file: bootstrap_500/P0504196/P0504196003/bootstrap_output/LE/P050419600303_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79431
# Standard deviation (error on period): 3.95171e-05
#
# Extracted -> Mean Period: 9.79431, Std Dev: 3.95171e-05
#
# Reading file: bootstrap_500/P0504196/P0504196003/bootstrap_output/LE/P050419600301_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79432
# Standard deviation (error on period): 2.90379e-05
#
# Extracted -> Mean Period: 9.79432, Std Dev: 2.90379e-05
#
# Reading file: bootstrap_500/P0504196/P0504196005/bootstrap_output/HE/P050419600502_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79389
# Standard deviation (error on period): 1.50864e-05
#
# Extracted -> Mean Period: 9.79389, Std Dev: 1.50864e-05
#
# Reading file: bootstrap_500/P0504196/P0504196005/bootstrap_output/HE/P050419600501_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79387
# Standard deviation (error on period): 1.53101e-05
#
# Extracted -> Mean Period: 9.79387, Std Dev: 1.53101e-05
#
# Reading file: bootstrap_500/P0504196/P0504196005/bootstrap_output/ME/P050419600501_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79397
# Standard deviation (error on period): 5.27257e-05
#
# Extracted -> Mean Period: 9.79397, Std Dev: 5.27257e-05
#
# Reading file: bootstrap_500/P0504196/P0504196005/bootstrap_output/ME/P050419600502_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79384
# Standard deviation (error on period): 3.39529e-05
#
# Extracted -> Mean Period: 9.79384, Std Dev: 3.39529e-05
#
# Reading file: bootstrap_500/P0504196/P0504196005/bootstrap_output/LE/P050419600502_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79371
# Standard deviation (error on period): 9.21683e-05
#
# Extracted -> Mean Period: 9.79371, Std Dev: 9.21683e-05
#
# Reading file: bootstrap_500/P0504196/P0504196005/bootstrap_output/LE/P050419600501_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79369
# Standard deviation (error on period): 8.34877e-05
#
# Extracted -> Mean Period: 9.79369, Std Dev: 8.34877e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/HE/P050419602207_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79223
# Standard deviation (error on period): 0.000158111
#
# Extracted -> Mean Period: 9.79223, Std Dev: 0.000158111
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/HE/P050419602201_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79256
# Standard deviation (error on period): 6.29444e-05
#
# Extracted -> Mean Period: 9.79256, Std Dev: 6.29444e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/HE/P050419602204_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79255
# Standard deviation (error on period): 6.35279e-05
#
# Extracted -> Mean Period: 9.79255, Std Dev: 6.35279e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/HE/P050419602203_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79255
# Standard deviation (error on period): 9.96995e-06
#
# Extracted -> Mean Period: 9.79255, Std Dev: 9.96995e-06
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/HE/P050419602211_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79243
# Standard deviation (error on period): 8.59767e-05
#
# Extracted -> Mean Period: 9.79243, Std Dev: 8.59767e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/HE/P050419602209_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79252
# Standard deviation (error on period): 4.63983e-05
#
# Extracted -> Mean Period: 9.79252, Std Dev: 4.63983e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/HE/P050419602205_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79317
# Standard deviation (error on period): 0.000385698
#
# Extracted -> Mean Period: 9.79317, Std Dev: 0.000385698
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/HE/P050419602210_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79276
# Standard deviation (error on period): 0.000427132
#
# Extracted -> Mean Period: 9.79276, Std Dev: 0.000427132
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/HE/P050419602206_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79257
# Standard deviation (error on period): 5.23737e-05
#
# Extracted -> Mean Period: 9.79257, Std Dev: 5.23737e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/HE/P050419602202_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79239
# Standard deviation (error on period): 7.89265e-05
#
# Extracted -> Mean Period: 9.79239, Std Dev: 7.89265e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/HE/P050419602208_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79251
# Standard deviation (error on period): 9.15423e-06
#
# Extracted -> Mean Period: 9.79251, Std Dev: 9.15423e-06
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/ME/P050419602211_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79247
# Standard deviation (error on period): 6.14264e-05
#
# Extracted -> Mean Period: 9.79247, Std Dev: 6.14264e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/ME/P050419602206_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79256
# Standard deviation (error on period): 5.27504e-05
#
# Extracted -> Mean Period: 9.79256, Std Dev: 5.27504e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/ME/P050419602205_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79258
# Standard deviation (error on period): 5.53715e-05
#
# Extracted -> Mean Period: 9.79258, Std Dev: 5.53715e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/ME/P050419602209_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79253
# Standard deviation (error on period): 4.45264e-05
#
# Extracted -> Mean Period: 9.79253, Std Dev: 4.45264e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/ME/P050419602203_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79257
# Standard deviation (error on period): 9.76729e-06
#
# Extracted -> Mean Period: 9.79257, Std Dev: 9.76729e-06
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/ME/P050419602210_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79251
# Standard deviation (error on period): 7.76698e-05
#
# Extracted -> Mean Period: 9.79251, Std Dev: 7.76698e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/ME/P050419602202_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79252
# Standard deviation (error on period): 5.75222e-05
#
# Extracted -> Mean Period: 9.79252, Std Dev: 5.75222e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/ME/P050419602207_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79257
# Standard deviation (error on period): 8.73808e-05
#
# Extracted -> Mean Period: 9.79257, Std Dev: 8.73808e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/ME/P050419602208_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79248
# Standard deviation (error on period): 7.42967e-06
#
# Extracted -> Mean Period: 9.79248, Std Dev: 7.42967e-06
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/ME/P050419602201_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79256
# Standard deviation (error on period): 4.37676e-05
#
# Extracted -> Mean Period: 9.79256, Std Dev: 4.37676e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/ME/P050419602204_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79248
# Standard deviation (error on period): 6.78867e-05
#
# Extracted -> Mean Period: 9.79248, Std Dev: 6.78867e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/LE/P050419602203_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79256
# Standard deviation (error on period): 2.79285e-06
#
# Extracted -> Mean Period: 9.79256, Std Dev: 2.79285e-06
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/LE/P050419602209_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79241
# Standard deviation (error on period): 0.000220914
#
# Extracted -> Mean Period: 9.79241, Std Dev: 0.000220914
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/LE/P050419602205_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79234
# Standard deviation (error on period): 0.00013669
#
# Extracted -> Mean Period: 9.79234, Std Dev: 0.00013669
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/LE/P050419602208_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79249
# Standard deviation (error on period): 9.94987e-06
#
# Extracted -> Mean Period: 9.79249, Std Dev: 9.94987e-06
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/LE/P050419602202_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.7925
# Standard deviation (error on period): 4.17684e-05
#
# Extracted -> Mean Period: 9.7925, Std Dev: 4.17684e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/LE/P050419602201_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79263
# Standard deviation (error on period): 7.68258e-05
#
# Extracted -> Mean Period: 9.79263, Std Dev: 7.68258e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/LE/P050419602206_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.7925
# Standard deviation (error on period): 6.00417e-05
#
# Extracted -> Mean Period: 9.7925, Std Dev: 6.00417e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/LE/P050419602210_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79236
# Standard deviation (error on period): 0.000138698
#
# Extracted -> Mean Period: 9.79236, Std Dev: 0.000138698
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/LE/P050419602211_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79252
# Standard deviation (error on period): 0.000102842
#
# Extracted -> Mean Period: 9.79252, Std Dev: 0.000102842
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/LE/P050419602207_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.7926
# Standard deviation (error on period): 1.82483e-05
#
# Extracted -> Mean Period: 9.7926, Std Dev: 1.82483e-05
#
# Reading file: bootstrap_500/P0504196/P0504196022/bootstrap_output/LE/P050419602204_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79241
# Standard deviation (error on period): 0.000207109
#
# Extracted -> Mean Period: 9.79241, Std Dev: 0.000207109
#
# Reading file: bootstrap_500/P0504196/P0504196015/bootstrap_output/HE/P050419601501_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79253
# Standard deviation (error on period): 5.81051e-05
#
# Extracted -> Mean Period: 9.79253, Std Dev: 5.81051e-05
#
# Reading file: bootstrap_500/P0504196/P0504196015/bootstrap_output/HE/P050419601502_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79236
# Standard deviation (error on period): 5.90745e-05
#
# Extracted -> Mean Period: 9.79236, Std Dev: 5.90745e-05
#
# Reading file: bootstrap_500/P0504196/P0504196015/bootstrap_output/ME/P050419601501_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79244
# Standard deviation (error on period): 2.86321e-05
#
# Extracted -> Mean Period: 9.79244, Std Dev: 2.86321e-05
#
# Reading file: bootstrap_500/P0504196/P0504196015/bootstrap_output/ME/P050419601502_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79252
# Standard deviation (error on period): 4.02492e-06
#
# Extracted -> Mean Period: 9.79252, Std Dev: 4.02492e-06
#
# Reading file: bootstrap_500/P0504196/P0504196015/bootstrap_output/LE/P050419601501_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79251
# Standard deviation (error on period): 2.70074e-05
#
# Extracted -> Mean Period: 9.79251, Std Dev: 2.70074e-05
#
# Reading file: bootstrap_500/P0504196/P0504196015/bootstrap_output/LE/P050419601502_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79247
# Standard deviation (error on period): 3.4389e-05
#
# Extracted -> Mean Period: 9.79247, Std Dev: 3.4389e-05
#
# Reading file: bootstrap_500/P0504196/P0504196017/bootstrap_output/HE/P050419601701_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79254
# Standard deviation (error on period): 2.9489e-05
#
# Extracted -> Mean Period: 9.79254, Std Dev: 2.9489e-05
#
# Reading file: bootstrap_500/P0504196/P0504196017/bootstrap_output/ME/P050419601701_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79247
# Standard deviation (error on period): 1.5225e-05
#
# Extracted -> Mean Period: 9.79247, Std Dev: 1.5225e-05
#
# Reading file: bootstrap_500/P0504196/P0504196017/bootstrap_output/LE/P050419601701_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79065
# Standard deviation (error on period): 0.00250459
#
# Extracted -> Mean Period: 9.79065, Std Dev: 0.00250459
#
# Reading file: bootstrap_500/P0504196/P0504196002/bootstrap_output/HE/P050419600202_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79449
# Standard deviation (error on period): 2.11234e-05
#
# Extracted -> Mean Period: 9.79449, Std Dev: 2.11234e-05
#
# Reading file: bootstrap_500/P0504196/P0504196002/bootstrap_output/HE/P050419600201_HE_lcnet_27-250keV_0.05s_all_t-chi1.qdp
# Mean period: 9.79467
# Standard deviation (error on period): 2.86984e-05
#
# Extracted -> Mean Period: 9.79467, Std Dev: 2.86984e-05
#
# Reading file: bootstrap_500/P0504196/P0504196002/bootstrap_output/ME/P050419600202_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79445
# Standard deviation (error on period): 2.46455e-05
#
# Extracted -> Mean Period: 9.79445, Std Dev: 2.46455e-05
#
# Reading file: bootstrap_500/P0504196/P0504196002/bootstrap_output/ME/P050419600201_ME_lcnet_10-35keV_0.05s_t-chi1.qdp
# Mean period: 9.79455
# Standard deviation (error on period): 4.51176e-05
#
# Extracted -> Mean Period: 9.79455, Std Dev: 4.51176e-05
#
# Reading file: bootstrap_500/P0504196/P0504196002/bootstrap_output/LE/P050419600201_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79438
# Standard deviation (error on period): 7.01926e-05
#
# Extracted -> Mean Period: 9.79438, Std Dev: 7.01926e-05
#
# Reading file: bootstrap_500/P0504196/P0504196002/bootstrap_output/LE/P050419600202_LE_lcnet_2-10keV_0.05s_t-chi1.qdp
# Mean period: 9.79446
# Standard deviation (error on period): 2.54008e-05
#
# Extracted -> Mean Period: 9.79446, Std Dev: 2.54008e-05
# Saved HE data to bootstrap_500/HE_period_data.csv
# Saved ME data to bootstrap_500/ME_period_data.csv
# Saved LE data to bootstrap_500/LE_period_data.csv
