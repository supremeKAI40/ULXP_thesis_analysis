# %%
import os
import subprocess
import numpy as np
import pandas as pd
from astropy.io import fits

# %%
# Define the file path (assuming it's in the same directory)
file_name = "all_lc_periods_evt_files_bary_orbit_piexpiex_manual.txt"

# Read the file, skipping comment lines (starting with ##)
df = pd.read_csv(file_name, sep='\s+', comment="#")

# Display the first few rows to check
print(df.head())

# Convert obsID column to string (in case it's read as an integer)
df["LC_File_Path"] = df["LC_File_Path"].astype(str)
# Out:
#    LC_File_Path   Period   Chi-square  TSTARTI        freq      PErr
# 0    6050390227  9.80076  21747.14844    20112  102.032904  0.000006
# 1    6050390228  9.80069  14779.15527    20113  102.033632  0.000010
# 2    6050390229  9.80057  20520.34570    20114  102.034882  0.000002
# 3    6050390230  9.80043  19369.66602    20115  102.036339  0.000024
# 4    6050390231  9.80052  24025.91992    20116  102.035402  0.000021

# %%
# Find all obsID folders in "reduced_output"
obsid_folders = [f.path for f in os.scandir("./reduced_output") if f.is_dir() and f.name.startswith("6050")]

# Define nphase values (modify if needed)
nphase = 64  # Or adjust based on requirements
epoch='20112.43542487309'

# Loop through each obsID folder
for obsid_folder in obsid_folders:
    obsid = os.path.basename(obsid_folder)
    print(f"Processing obsID: {obsid}")

    # Find the period for this obsID from the DataFrame
    period_row = df[df["LC_File_Path"] == obsid]
    
    if period_row.empty:
        print(f"No period found for obsID: {obsid}, skipping.")
        continue

    period = period_row["Period"].values[0]

    # Find the correct light curve files
    lc_files = []
    for root, dirs, files in os.walk(obsid_folder):
        for file in files:
            if file.endswith("cl_night_barycorr_orbit_piexpiex.evt"):
            #if file.endswith("cl_nightmpu7_sr_night_barycorr_orbit.lc"): ### From LC 
                lc_files.append(os.path.join(root, file))

    if not lc_files:
        print(f"No light curve files found for obsID: {obsid}")
        continue

    print(f"Found {len(lc_files)} light curve files for obsID {obsid} with period {period}.")

    # Define output base directory
    output_base = "./folded_curves"
    os.makedirs(output_base, exist_ok=True)  # Create main output folder if not exists
    # Create obsID-specific output folder
    obsid_output_dir = os.path.join(output_base, obsid)
    os.makedirs(obsid_output_dir, exist_ok=True)

    # Run efold for each LC file
    for lc_file in lc_files:
        light_curve_file = lc_file
        output_profile = os.path.join(obsid_output_dir, f"{obsid}_pulse_profile_efold_same_epoch.fits")

        print("runs")

        # Constructing the efold command with all required flags
        cmd = (
            f"echo '-' | efold 1 {lc_file} "
            f"outfile={output_profile} "
            f"dper={period} "
            f"nphase={nphase} "
            f"epochfo=1 "
            f"sepoch={epoch} "
            f"nbint=INDEF "
            f"nintfm=INDEF "
            f"plot=no "
            f"norm=0"
        )

        print(f"Running: {cmd}")
        subprocess.run(cmd, shell=True, check=True)
        break

print("All processing completed!")
# Out:
# Processing obsID: 6050390261
# Found 1 light curve files for obsID 6050390261 with period 9.7925.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390261/ni6050390261_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390261/6050390261_pulse_profile_efold_same_epoch.fits dper=9.7925 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390261/ni6050390261_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20174 01:46:47.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20174 20:33:45.184
#  No. of Rows .......      1013196        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20174 01:46:47.184
#  No. of Rows .......            3        Last GTI Stop ..... 20174 20:33:45.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20174.07415722222  (days)       1:46:47:184  (h:m:s:ms)
#  Expected Stop .... 20174.85677296296  (days)      20:33:45:184  (h:m:s:ms)
#
#  Default Epoch is:  20174.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6905.08
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15300781      (s)
#  Maximum Newbin No.            441926
#
#  Default Newbins per Interval are:      441926
#  (giving       1 Interval of       441926 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       441926 Newbins of      0.153008     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
#  99% completed
#  Intv    1   Start 20174  1:46:46
#      Ser.1     Avg  502.2        Chisq 0.1718E+05   Var  4333.     Newbs.     64
#                Min  376.2          Max  589.6    expVar  16.15      Bins1011754
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390261/6050390261_pulse_profile_efold_s
# 100% completed
# Interval 2 rejected; all bins zero
#
# Processing obsID: 6050390212
# No period found for obsID: 6050390212, skipping.
# Processing obsID: 6050390240
# Found 1 light curve files for obsID 6050390240 with period 9.79962.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390240/ni6050390240_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390240/6050390240_pulse_profile_efold_same_epoch.fits dper=9.79962 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390240/ni6050390240_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20125 14:15:55.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20125 17:31:28.184
#  No. of Rows .......      1929170        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20125 14:15:55.184
#  No. of Rows .......            3        Last GTI Stop ..... 20125 17:31:28.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20125.59438870370  (days)      14:15:55:184  (h:m:s:ms)
#  Expected Stop .... 20125.73018731481  (days)      17:31:28:184  (h:m:s:ms)
#
#  Default Epoch is:  20125.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           1197.29
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15311906      (s)
#  Maximum Newbin No.             76627
#
#  Default Newbins per Interval are:       76627
#  (giving       1 Interval of        76627 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with        76627 Newbins of      0.153119     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20125 14:15:54
#      Ser.1     Avg  1015.        Chisq 0.3467E+05   Var 0.1981E+05 Newbs.     64
#                Min  817.9          Max  1238.    expVar  36.48      Bins1929170
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390240/6050390240_pulse_profile_efold_s
# Processing obsID: 6050390251
# Found 1 light curve files for obsID 6050390251 with period 9.7959.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390251/ni6050390251_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390251/6050390251_pulse_profile_efold_same_epoch.fits dper=9.7959 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390251/ni6050390251_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20144 05:58:12.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20144 17:04:09.184
#  No. of Rows .......      2431943        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20144 05:58:12.184
#  No. of Rows .......            2        Last GTI Stop ..... 20144 17:04:09.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20144.24875212963  (days)       5:58:12:184  (h:m:s:ms)
#  Expected Stop .... 20144.71121740741  (days)      17: 4: 9:184  (h:m:s:ms)
#
#  Default Epoch is:  20144.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           4078.95
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15306094      (s)
#  Maximum Newbin No.            261053
#
#  Default Newbins per Interval are:      261053
#  (giving       1 Interval of       261053 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       261053 Newbins of      0.153061     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20144  5:58:11
#      Ser.1     Avg  1356.        Chisq 0.4214E+05   Var 0.3815E+05 Newbs.     64
#                Min  1069.          Max  1652.    expVar  57.91      Bins2431943
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390251/6050390251_pulse_profile_efold_s
# Processing obsID: 6050390249
# Found 1 light curve files for obsID 6050390249 with period 9.7928.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390249/ni6050390249_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390249/6050390249_pulse_profile_efold_same_epoch.fits dper=9.7928 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390249/ni6050390249_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20142 10:43:21.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20142 10:53:49.184
#  No. of Rows .......      1045758        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20142 10:43:21.184
#  No. of Rows .......            1        Last GTI Stop ..... 20142 10:53:49.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20142.44677296296  (days)      10:43:21:184  (h:m:s:ms)
#  Expected Stop .... 20142.45404148148  (days)      10:53:49:184  (h:m:s:ms)
#
#  Default Epoch is:  20142.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..             64.13
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15301250      (s)
#  Maximum Newbin No.              4105
#
#  Default Newbins per Interval are:        4105
#  (giving       1 Interval of         4105 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with         4105 Newbins of      0.153012     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20142 10:43:20
#      Ser.1     Avg  908.7        Chisq 0.1051E+05   Var 0.1521E+05 Newbs.     64
#                Min  749.5          Max  1119.    expVar  92.63      Bins1045758
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390249/6050390249_pulse_profile_efold_s
# Processing obsID: 6050390230
# Found 1 light curve files for obsID 6050390230 with period 9.80043.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390230/ni6050390230_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390230/6050390230_pulse_profile_efold_same_epoch.fits dper=9.80043 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390230/ni6050390230_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20115 17:28:55.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20115 22:14:31.184
#  No. of Rows .......      1220445        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20115 17:28:55.184
#  No. of Rows .......            4        Last GTI Stop ..... 20115 22:14:31.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20115.72841648148  (days)      17:28:55:184  (h:m:s:ms)
#  Expected Stop .... 20115.92674981481  (days)      22:14:31:184  (h:m:s:ms)
#
#  Default Epoch is:  20115.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           1748.49
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15313172      (s)
#  Maximum Newbin No.            111904
#
#  Default Newbins per Interval are:      111904
#  (giving       1 Interval of       111904 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       111904 Newbins of      0.153132     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20115 17:28:54
#      Ser.1     Avg  642.3        Chisq 0.1937E+05   Var  7591.     Newbs.     64
#                Min  547.2          Max  799.9    expVar  25.09      Bins1220445
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390230/6050390230_pulse_profile_efold_s
# Processing obsID: 6050390206
# No period found for obsID: 6050390206, skipping.
# Processing obsID: 6050390223
# No period found for obsID: 6050390223, skipping.
# Processing obsID: 6050390243
# Found 1 light curve files for obsID 6050390243 with period 9.79882.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390243/ni6050390243_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390243/6050390243_pulse_profile_efold_same_epoch.fits dper=9.79882 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390243/ni6050390243_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20128 14:59:16.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20128 22:53:29.184
#  No. of Rows .......      1907269        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20128 14:59:16.184
#  No. of Rows .......            3        Last GTI Stop ..... 20128 22:53:29.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20128.62449287037  (days)      14:59:16:184  (h:m:s:ms)
#  Expected Stop .... 20128.95381000000  (days)      22:53:29:184  (h:m:s:ms)
#
#  Default Epoch is:  20128.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           2903.72
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15310656      (s)
#  Maximum Newbin No.            185838
#
#  Default Newbins per Interval are:      185838
#  (giving       1 Interval of       185838 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       185838 Newbins of      0.153107     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20128 14:59:15
#      Ser.1     Avg  815.4        Chisq 0.2889E+05   Var 0.1294E+05 Newbs.     64
#                Min  654.6          Max  984.4    expVar  28.69      Bins1907269
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390243/6050390243_pulse_profile_efold_s
# Processing obsID: 6050390204
# No period found for obsID: 6050390204, skipping.
# Processing obsID: 6050390242
# Found 1 light curve files for obsID 6050390242 with period 9.79903.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390242/ni6050390242_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390242/6050390242_pulse_profile_efold_same_epoch.fits dper=9.79903 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390242/ni6050390242_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20127 18:52:14.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20127 22:08:07.184
#  No. of Rows .......      1412168        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20127 18:52:14.184
#  No. of Rows .......            6        Last GTI Stop ..... 20127 22:08:07.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20127.78627527778  (days)      18:52:14:184  (h:m:s:ms)
#  Expected Stop .... 20127.92230537037  (days)      22: 8: 7:184  (h:m:s:ms)
#
#  Default Epoch is:  20127.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           1199.40
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15310984      (s)
#  Maximum Newbin No.             76762
#
#  Default Newbins per Interval are:       76762
#  (giving       1 Interval of        76762 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with        76762 Newbins of      0.153110     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20127 18:52:13
#      Ser.1     Avg  685.8        Chisq 0.2454E+05   Var  9206.     Newbs.     64
#                Min  537.1          Max  831.7    expVar  24.03      Bins1412168
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390242/6050390242_pulse_profile_efold_s
# Processing obsID: 6050390272
# Found 1 light curve files for obsID 6050390272 with period 9.7919.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390272/ni6050390272_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390272/6050390272_pulse_profile_efold_same_epoch.fits dper=9.7919 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390272/ni6050390272_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20187 18:11:32.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20187 19:51:45.184
#  No. of Rows .......       124502        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20187 18:11:32.184
#  No. of Rows .......            2        Last GTI Stop ..... 20187 19:51:45.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20187.75801138889  (days)      18:11:32:184  (h:m:s:ms)
#  Expected Stop .... 20187.82760629629  (days)      19:51:45:184  (h:m:s:ms)
#
#  Default Epoch is:  20187.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..            614.08
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15299844      (s)
#  Maximum Newbin No.             39302
#
#  Default Newbins per Interval are:       39302
#  (giving       1 Interval of        39302 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with        39302 Newbins of      0.152998     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20187 18:11:31
#      Ser.1     Avg  138.9        Chisq  2076.       Var  326.3     Newbs.     64
#                Min  106.1          Max  176.4    expVar  10.12      Bins 124502
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390272/6050390272_pulse_profile_efold_s
# Processing obsID: 6050390271
# No period found for obsID: 6050390271, skipping.
# Processing obsID: 6050390254
# Found 1 light curve files for obsID 6050390254 with period 9.79568.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390254/ni6050390254_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390254/6050390254_pulse_profile_efold_same_epoch.fits dper=9.79568 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390254/ni6050390254_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20147 00:39:01.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20147 19:14:49.184
#  No. of Rows .......      3032656        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20147 00:39:01.184
#  No. of Rows .......            5        Last GTI Stop ..... 20147 19:14:49.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20147.02709703704  (days)       0:39: 1:184  (h:m:s:ms)
#  Expected Stop .... 20147.80195814815  (days)      19:14:49:184  (h:m:s:ms)
#
#  Default Epoch is:  20147.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6834.44
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15305750      (s)
#  Maximum Newbin No.            437405
#
#  Default Newbins per Interval are:      437405
#  (giving       1 Interval of       437405 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       437405 Newbins of      0.153058     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20147  0:39: 0
#      Ser.1     Avg  1455.        Chisq 0.5365E+05   Var 0.4084E+05 Newbs.     64
#                Min  1117.          Max  1738.    expVar  48.80      Bins3032656
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390254/6050390254_pulse_profile_efold_s
# Processing obsID: 6050390279
# Found 1 light curve files for obsID 6050390279 with period 9.7918.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390279/ni6050390279_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390279/6050390279_pulse_profile_efold_same_epoch.fits dper=9.7918 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390279/ni6050390279_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20195 04:14:48.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20195 10:34:27.184
#  No. of Rows .......       128640        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20195 04:14:48.184
#  No. of Rows .......            6        Last GTI Stop ..... 20195 10:34:27.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20195.17694657407  (days)       4:14:48:184  (h:m:s:ms)
#  Expected Stop .... 20195.44059240741  (days)      10:34:27:184  (h:m:s:ms)
#
#  Default Epoch is:  20195.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           2326.33
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15299688      (s)
#  Maximum Newbin No.            148886
#
#  Default Newbins per Interval are:      148886
#  (giving       1 Interval of       148886 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       148886 Newbins of      0.152997     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20195  4:14:47
#      Ser.1     Avg  57.61        Chisq  1380.       Var  35.94     Newbs.     64
#                Min  48.63          Max  68.08    expVar  1.671      Bins 128640
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390279/6050390279_pulse_profile_efold_s
# Processing obsID: 6050390268
# Found 1 light curve files for obsID 6050390268 with period 9.7905.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390268/ni6050390268_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390268/6050390268_pulse_profile_efold_same_epoch.fits dper=9.7905 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390268/ni6050390268_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20183 10:24:38.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20183 10:34:54.184
#  No. of Rows .......       126415        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20183 10:24:38.184
#  No. of Rows .......            1        Last GTI Stop ..... 20183 10:34:54.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20183.43377527778  (days)      10:24:38:184  (h:m:s:ms)
#  Expected Stop .... 20183.44090490741  (days)      10:34:54:184  (h:m:s:ms)
#
#  Default Epoch is:  20183.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..             62.92
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15297656      (s)
#  Maximum Newbin No.              4027
#
#  Default Newbins per Interval are:        4027
#  (giving       1 Interval of         4027 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with         4027 Newbins of      0.152977     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
#  89% completed
#  Intv    1   Start 20183 10:24:37
#      Ser.1     Avg  183.4        Chisq  1407.       Var  417.9     Newbs.     64
#                Min  132.1          Max  222.8    expVar  19.06      Bins 112981
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390268/6050390268_pulse_profile_efold_s
# 100% completed
# Interval 2 rejected; all bins zero
#
# Processing obsID: 6050390239
# Found 1 light curve files for obsID 6050390239 with period 9.7999.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390239/ni6050390239_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390239/6050390239_pulse_profile_efold_same_epoch.fits dper=9.7999 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390239/ni6050390239_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20124 02:40:37.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20124 13:40:10.184
#  No. of Rows .......      2400023        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20124 02:40:37.184
#  No. of Rows .......            4        Last GTI Stop ..... 20124 13:40:10.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20124.11154148148  (days)       2:40:37:184  (h:m:s:ms)
#  Expected Stop .... 20124.56956231481  (days)      13:40:10:184  (h:m:s:ms)
#
#  Default Epoch is:  20124.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           4038.10
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312344      (s)
#  Maximum Newbin No.            258439
#
#  Default Newbins per Interval are:      258439
#  (giving       1 Interval of       258439 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       258439 Newbins of      0.153123     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20124  2:40:36
#      Ser.1     Avg  977.0        Chisq 0.4221E+05   Var 0.1764E+05 Newbs.     64
#                Min  798.9          Max  1169.    expVar  26.79      Bins2400023
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390239/6050390239_pulse_profile_efold_s
# Processing obsID: 6050390278
# No period found for obsID: 6050390278, skipping.
# Processing obsID: 6050390232
# Found 1 light curve files for obsID 6050390232 with period 9.80042.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390232/ni6050390232_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390232/6050390232_pulse_profile_efold_same_epoch.fits dper=9.80042 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390232/ni6050390232_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20117 00:28:37.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20117 23:47:19.184
#  No. of Rows .......      4223399        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20117 00:28:37.184
#  No. of Rows .......           10        Last GTI Stop ..... 20117 23:47:19.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20117.01987481481  (days)       0:28:37:184  (h:m:s:ms)
#  Expected Stop .... 20117.99119425926  (days)      23:47:19:184  (h:m:s:ms)
#
#  Default Epoch is:  20117.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           8563.10
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15313156      (s)
#  Maximum Newbin No.            548039
#
#  Default Newbins per Interval are:      548039
#  (giving       1 Interval of       548039 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       548039 Newbins of      0.153132     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20117  0:28:36
#      Ser.1     Avg  1098.        Chisq 0.7655E+05   Var 0.2314E+05 Newbs.     64
#                Min  939.0          Max  1352.    expVar  19.28      Bins4223399
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390232/6050390232_pulse_profile_efold_s
# Processing obsID: 6050390273
# No period found for obsID: 6050390273, skipping.
# Processing obsID: 6050390233
# Found 1 light curve files for obsID 6050390233 with period 9.80037.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390233/ni6050390233_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390233/6050390233_pulse_profile_efold_same_epoch.fits dper=9.80037 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390233/ni6050390233_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20118 02:44:58.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20118 23:00:39.184
#  No. of Rows .......      5601143        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20118 02:44:58.184
#  No. of Rows .......           14        Last GTI Stop ..... 20118 23:00:39.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20118.11456231481  (days)       2:44:58:184  (h:m:s:ms)
#  Expected Stop .... 20118.95878685185  (days)      23: 0:39:184  (h:m:s:ms)
#
#  Default Epoch is:  20118.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           7442.68
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15313078      (s)
#  Maximum Newbin No.            476332
#
#  Default Newbins per Interval are:      476332
#  (giving       1 Interval of       476332 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       476332 Newbins of      0.153131     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20118  2:44:57
#      Ser.1     Avg  1116.        Chisq 0.8727E+05   Var 0.2107E+05 Newbs.     64
#                Min  957.2          Max  1346.    expVar  15.47      Bins5601143
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390233/6050390233_pulse_profile_efold_s
# Processing obsID: 6050390234
# Found 1 light curve files for obsID 6050390234 with period 9.80032.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390234/ni6050390234_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390234/6050390234_pulse_profile_efold_same_epoch.fits dper=9.80032 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390234/ni6050390234_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20119 00:25:14.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20119 17:35:15.184
#  No. of Rows .......      5208303        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20119 00:25:14.184
#  No. of Rows .......           10        Last GTI Stop ..... 20119 17:35:15.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20119.01752527778  (days)       0:25:14:184  (h:m:s:ms)
#  Expected Stop .... 20119.73281462963  (days)      17:35:15:184  (h:m:s:ms)
#
#  Default Epoch is:  20119.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6306.02
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15313000      (s)
#  Maximum Newbin No.            403586
#
#  Default Newbins per Interval are:      403586
#  (giving       1 Interval of       403586 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       403586 Newbins of      0.153130     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20119  0:25:13
#      Ser.1     Avg  971.5        Chisq 0.8853E+05   Var 0.1672E+05 Newbs.     64
#                Min  812.6          Max  1167.    expVar  12.09      Bins5208303
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390234/6050390234_pulse_profile_efold_s
# Processing obsID: 6050390238
# Found 1 light curve files for obsID 6050390238 with period 9.79997.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390238/ni6050390238_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390238/6050390238_pulse_profile_efold_same_epoch.fits dper=9.79997 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390238/ni6050390238_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20123 00:24:02.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20123 17:33:03.184
#  No. of Rows .......      4402479        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20123 00:24:02.184
#  No. of Rows .......            9        Last GTI Stop ..... 20123 17:33:03.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20123.01669194444  (days)       0:24: 2:184  (h:m:s:ms)
#  Expected Stop .... 20123.73128685185  (days)      17:33: 3:184  (h:m:s:ms)
#
#  Default Epoch is:  20123.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6300.12
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312453      (s)
#  Maximum Newbin No.            403208
#
#  Default Newbins per Interval are:      403208
#  (giving       1 Interval of       403208 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       403208 Newbins of      0.153125     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20123  0:24: 1
#      Ser.1     Avg  1100.        Chisq 0.7167E+05   Var 0.2154E+05 Newbs.     64
#                Min  900.0          Max  1325.    expVar  19.22      Bins4402479
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390238/6050390238_pulse_profile_efold_s
# Processing obsID: 6050390277
# No period found for obsID: 6050390277, skipping.
# Processing obsID: 6050390258
# Found 1 light curve files for obsID 6050390258 with period 9.7925.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390258/ni6050390258_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390258/6050390258_pulse_profile_efold_same_epoch.fits dper=9.7925 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390258/ni6050390258_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20171 04:07:16.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20171 22:49:12.184
#  No. of Rows .......      1296042        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20171 04:07:16.184
#  No. of Rows .......            4        Last GTI Stop ..... 20171 22:49:12.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20171.17171509259  (days)       4: 7:16:184  (h:m:s:ms)
#  Expected Stop .... 20171.95083546296  (days)      22:49:12:184  (h:m:s:ms)
#
#  Default Epoch is:  20171.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6874.24
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15300781      (s)
#  Maximum Newbin No.            439952
#
#  Default Newbins per Interval are:      439952
#  (giving       1 Interval of       439952 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       439952 Newbins of      0.153008     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20171  4: 7:15
#      Ser.1     Avg  596.6        Chisq 0.1996E+05   Var  5768.     Newbs.     64
#                Min  457.6          Max  711.0    expVar  18.51      Bins1296042
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390258/6050390258_pulse_profile_efold_s
# Processing obsID: 6050390241
# Found 1 light curve files for obsID 6050390241 with period 9.79907.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390241/ni6050390241_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390241/6050390241_pulse_profile_efold_same_epoch.fits dper=9.79907 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390241/ni6050390241_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20126 18:07:43.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20126 21:22:41.184
#  No. of Rows .......      1154634        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20126 18:07:43.184
#  No. of Rows .......            9        Last GTI Stop ..... 20126 21:22:41.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20126.75536092593  (days)      18: 7:43:184  (h:m:s:ms)
#  Expected Stop .... 20126.89075444444  (days)      21:22:41:184  (h:m:s:ms)
#
#  Default Epoch is:  20126.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           1193.79
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15311047      (s)
#  Maximum Newbin No.             76403
#
#  Default Newbins per Interval are:       76403
#  (giving       1 Interval of        76403 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with        76403 Newbins of      0.153110     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20126 18: 7:42
#      Ser.1     Avg  822.9        Chisq 0.1661E+05   Var 0.1179E+05 Newbs.     64
#                Min  658.4          Max  978.9    expVar  45.42      Bins1154634
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390241/6050390241_pulse_profile_efold_s
# Processing obsID: 6050390283
# No period found for obsID: 6050390283, skipping.
# Processing obsID: 6050390203
# No period found for obsID: 6050390203, skipping.
# Processing obsID: 6050390235
# Found 1 light curve files for obsID 6050390235 with period 9.80028.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390235/ni6050390235_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390235/6050390235_pulse_profile_efold_same_epoch.fits dper=9.80028 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
# ...
# 100% completed
# Interval 2 rejected; all bins zero
#
# Processing obsID: 6050390247
# Found 1 light curve files for obsID 6050390247 with period 9.79506.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390247/ni6050390247_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390247/6050390247_pulse_profile_efold_same_epoch.fits dper=9.79506 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390247/ni6050390247_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20140 07:32:37.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20140 16:58:38.184
#  No. of Rows .......      1734015        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20140 07:32:37.184
#  No. of Rows .......            2        Last GTI Stop ..... 20140 16:58:38.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20140.31431925926  (days)       7:32:37:184  (h:m:s:ms)
#  Expected Stop .... 20140.70738638889  (days)      16:58:38:184  (h:m:s:ms)
#
#  Default Epoch is:  20140.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           3467.16
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15304781      (s)
#  Maximum Newbin No.            221898
#
#  Default Newbins per Interval are:      221898
#  (giving       1 Interval of       221898 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       221898 Newbins of      0.153048     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20140  7:32:36
#      Ser.1     Avg  1181.        Chisq 0.2619E+05   Var 0.2936E+05 Newbs.     64
#                Min  936.5          Max  1434.    expVar  71.81      Bins1734015
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390247/6050390247_pulse_profile_efold_s
# Processing obsID: 6050390253
# Found 1 light curve files for obsID 6050390253 with period 9.79577.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390253/ni6050390253_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390253/6050390253_pulse_profile_efold_same_epoch.fits dper=9.79577 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390253/ni6050390253_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20146 12:18:35.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20146 18:33:09.184
#  No. of Rows .......      1417832        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20146 12:18:35.184
#  No. of Rows .......            4        Last GTI Stop ..... 20146 18:33:09.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20146.51290722222  (days)      12:18:35:184  (h:m:s:ms)
#  Expected Stop .... 20146.77302296296  (days)      18:33: 9:184  (h:m:s:ms)
#
#  Default Epoch is:  20146.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           2294.26
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15305891      (s)
#  Maximum Newbin No.            146833
#
#  Default Newbins per Interval are:      146833
#  (giving       1 Interval of       146833 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       146833 Newbins of      0.153059     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20146 12:18:34
#      Ser.1     Avg  1394.        Chisq 0.3470E+05   Var 0.5963E+05 Newbs.     64
#                Min  976.2          Max  1717.    expVar  109.4      Bins1417832
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390253/6050390253_pulse_profile_efold_s
# Processing obsID: 6050390222
# No period found for obsID: 6050390222, skipping.
# Processing obsID: 6050390229
# Found 1 light curve files for obsID 6050390229 with period 9.80057.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390229/ni6050390229_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390229/6050390229_pulse_profile_efold_same_epoch.fits dper=9.80057 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390229/ni6050390229_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20114 01:14:15.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20114 21:28:00.184
#  No. of Rows .......      1837272        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20114 01:14:15.184
#  No. of Rows .......            6        Last GTI Stop ..... 20114 21:28:00.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20114.05156462963  (days)       1:14:15:184  (h:m:s:ms)
#  Expected Stop .... 20114.89444657407  (days)      21:28: 0:184  (h:m:s:ms)
#
#  Default Epoch is:  20114.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           7430.69
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15313391      (s)
#  Maximum Newbin No.            475565
#
#  Default Newbins per Interval are:      475565
#  (giving       1 Interval of       475565 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       475565 Newbins of      0.153134     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20114  1:14:14
#      Ser.1     Avg  720.2        Chisq 0.2054E+05   Var  6764.     Newbs.     64
#                Min  619.0          Max  873.9    expVar  21.15      Bins1837272
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390229/6050390229_pulse_profile_efold_s
# Processing obsID: 6050390217
# No period found for obsID: 6050390217, skipping.
# Processing obsID: 6050390246
# Found 1 light curve files for obsID 6050390246 with period 9.79933.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390246/ni6050390246_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390246/6050390246_pulse_profile_efold_same_epoch.fits dper=9.79933 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390246/ni6050390246_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20134 13:27:04.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20134 18:09:51.184
#  No. of Rows .......       802590        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20134 13:27:04.184
#  No. of Rows .......            2        Last GTI Stop ..... 20134 18:09:51.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20134.56046509259  (days)      13:27: 4:184  (h:m:s:ms)
#  Expected Stop .... 20134.75684240741  (days)      18: 9:51:184  (h:m:s:ms)
#
#  Default Epoch is:  20134.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           1731.44
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15311453      (s)
#  Maximum Newbin No.            110813
#
#  Default Newbins per Interval are:      110813
#  (giving       1 Interval of       110813 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       110813 Newbins of      0.153115     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
# 100% completed
#
#  Intv    1   Start 20134 13:27: 3
#      Ser.1     Avg  657.2        Chisq  6731.       Var  9181.     Newbs.     64
#                Min  516.5          Max  815.3    expVar  87.39      Bins 802590
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390246/6050390246_pulse_profile_efold_s
# Processing obsID: 6050390269
# Found 1 light curve files for obsID 6050390269 with period 9.79426.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390269/ni6050390269_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390269/6050390269_pulse_profile_efold_same_epoch.fits dper=9.79426 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390269/ni6050390269_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20184 05:07:05.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20184 17:32:59.184
#  No. of Rows .......       103403        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20184 05:07:05.184
#  No. of Rows .......            2        Last GTI Stop ..... 20184 17:32:59.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20184.21325444444  (days)       5: 7: 5:184  (h:m:s:ms)
#  Expected Stop .... 20184.73124055555  (days)      17:32:59:184  (h:m:s:ms)
#
#  Default Epoch is:  20184.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           4569.41
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15303531      (s)
#  Maximum Newbin No.            292443
#
#  Default Newbins per Interval are:      292443
#  (giving       1 Interval of       292443 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       292443 Newbins of      0.153035     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
#  92% completed
#  Intv    1   Start 20184  5: 7: 4
#      Ser.1     Avg  175.2        Chisq  1735.       Var  570.4     Newbs.     64
#                Min  121.1          Max  225.5    expVar  20.52      Bins  95760
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390269/6050390269_pulse_profile_efold_s
# 100% completed
# Interval 2 rejected; all bins zero
#
# Processing obsID: 6050390226
# No period found for obsID: 6050390226, skipping.
# Processing obsID: 6050390264
# Found 1 light curve files for obsID 6050390264 with period 9.7883.
# runs
# Running: echo '-' | efold 1 ./reduced_output/6050390264/ni6050390264_0mpu7_cl_night_barycorr_orbit_piexpiex.evt outfile=./folded_curves/6050390264/6050390264_pulse_profile_efold_same_epoch.fits dper=9.7883 nphase=64 epochfo=1 sepoch=20112.43542487309 nbint=INDEF nintfm=INDEF plot=no norm=0
#
# efold 1.2 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390264/ni6050390264_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20177 04:14:45.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20177 22:56:00.184
#  No. of Rows .......       251171        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20177 04:14:45.184
#  No. of Rows .......            2        Last GTI Stop ..... 20177 22:56:00.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
# Name of the window file ('-' for default window)[-] -
#
#  Expected Start ... 20177.17691185185  (days)       4:14:45:184  (h:m:s:ms)
#  Expected Stop .... 20177.95555768519  (days)      22:56: 0:184  (h:m:s:ms)
#
#  Default Epoch is:  20177.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6873.00
#  Default phase bins per period are:        10
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15294219      (s)
#  Maximum Newbin No.            439873
#
#  Default Newbins per Interval are:      439873
#  (giving       1 Interval of       439873 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       439873 Newbins of      0.152942     (s)
# Default intervals per frame are:         1
# Type INDEF to accept the default value
#  Results from up to       1 Intvs. will be averaged in a Frame
#
#       64 analysis results per interval
#
#  88% completed
#  Intv    1   Start 20177  4:14:44
#      Ser.1     Avg  353.2        Chisq  4781.       Var  2682.     Newbs.     64
#                Min  246.9          Max  423.6    expVar  36.06      Bins 221375
#   Folded light curve ready
# Writing output file: ./folded_curves/6050390264/6050390264_pulse_profile_efold_s
# 100% completed
# Interval 2 rejected; all bins zero
#
# All processing completed!
