# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
import os
import re

#Source code page: http://astro.uni-tuebingen.de/software/idl/aitlib/astro/binarycor.html
#Source code link: http://astro.uni-tuebingen.de/software/idl/aitlib/astro/binarycor.pro

# %%
def Binary_orbit(time,asini,porb,ecc,omega_d,t0=-1,t90=-1,pporb=0.0,limit=1.0*10**-10,maxiter=40):

	time=np.array(time)  #time should be an array to prevent round-off errors
	if t90==-1 and t0==-1:
		print("error: need t90 or t0 value")
		return

	if t90!=-1 and t0!=-1:
		print("error: Only one of the t90 and t0 arguments is allowed")
		return

	if ecc<0 :
		print("error: eccentricity must be positive!")
		return
	if ecc>=1:
		print("error: Orbit correction has only been implemented for circular and elliptic orbits")
		return
	if ecc==0:
		omega_d=0 #circular orbit
	
	
	if t0==-1:
		t0 = t90+(omega_d-90.)/360. * porb
		#print(t0,t90,"Debuggin time")
	if maxiter <=0:
		maxiter=20

	asini_d = asini/86400. #86400 seconds in a day, unit is light day
	t= time

	#Corrections for eccentricity 0<=ecc<1
	omega = omega_d * np.pi/180.0 # Radians conversion
	sinw = np.sin(omega)
	cosw = np.cos(omega)
	sq = ((1.-ecc)*(1.+ecc))**0.5
	cor =np.array([2.*limit]*len(t))
	

	#start with number of iterations = zero
	numiter=0
			
	contada=0
	print('starting iterations (max 20)')
	while((abs(np.amax(cor)) > limit) and (numiter < maxiter)):
		tper = (t-t0)/porb
		# Calculate the mean anomaly
		m = 2 * np.pi * (tper * (1. - 0.5 * pporb * tper))

		# Normalize m to the range [0, 2π]
		m = m % (2 * np.pi)

		# Shift m to the range [-π, π] if needed
		m[m > np.pi] -= 2 * np.pi

		m=np.array(m)

		print("Mean Anomaly:" ,m)
		
		eanom=np.array([1.0]*len(t))
		eanom = KeplerEquation1(m,ecc)  #use this command for a better solution
		
		print("Eccentric Anomaly:", eanom)  # Debugging line

		sin_e = np.sin(eanom)
		cos_e = np.cos(eanom)
		z = asini_d*(sinw*(cos_e-ecc)+sq*cosw*sin_e) ##Romer Delay Term
		f = (t-time)+z                               
		df = (sq*cosw*cos_e - sinw*sin_e)*(2*np.pi*asini_d/(porb*(1.0-ecc*cos_e)))
		cor =f/(1.0+df)
		t = t-cor #### Altering it to add this time 
		numiter=numiter+1
		contada=contada+1
		print('iteration ' + str(contada)+' completed (max 20)')
		if numiter >= maxiter:
			print("Exceeded maxiter iterations and did not reach convergence");
			break
	return(t)

# %%
def KeplerEquation1(m,ecc):
	m=np.array(m)
	if ecc<0 :
		print("error: eccentricity must be positive!")
		return
	if ecc>=1:
		print("error: Orbit correction has only been implemented for circular and elliptic orbits")
	
	#print("Mean anomaly input to kepler:", m)
	for j in range(0,len(m)):
		mod_m=m[j]/2/np.pi
		m[j]=m[j]-2*np.pi*round(mod_m)
		# if j==round(len(m)*0.1):print(10,"%")
		# if j==round(len(m)*0.2):print(20,"%")
		# if j==round(len(m)*0.3):print(30,"%")
		# if j==round(len(m)*0.4):print(40,"%")
		# if j==round(len(m)*0.5):print(50,"%")
		# if j==round(len(m)*0.6):print(60,"%")
		# if j==round(len(m)*0.7):print(70,"%")
		# if j==round(len(m)*0.8):print(80,"%")
		# if j==round(len(m)*0.9):print(90,"%")
		# if j==len(m)-1:print(100,"%")
		
		while m[j]>np.pi:
			m[j]=m[j]-2*np.pi
		while m[j]<-np.pi:
			m[j]=m[j]+2*np.pi
	if ecc==0:
		E=m
		
	aux=4.0*ecc+0.5
	alpha=(1.0-ecc)/aux
	
	Beta=m/(2.0*aux)
	aux=np.sqrt(Beta**2+alpha**3)
	
	z=Beta+aux
	test=np.array([1.0]*len(z))
	for j in range(0,len(m)):
		if z[j]<=0.0:
			z[j]=Beta[j]-aux[j]
			
		test[j]=abs(z[j])**(1/3)
	z=test
	for j in range(0,len(m)):
		if z[j]<0.0:
			z[j]=-z[j]
	s0=z-alpha/z
	
	s1=s0-(0.078*s0**5)/(1.0+ecc)
	e0=m+ecc*(3.0*s1-4.0*s1**3)	
	
	se0=np.sin(e0)
	ce0=np.cos(e0)
	
	##Newton Raphson method
	f  = e0-ecc*se0-m
	f1 = 1.0-ecc*ce0
	f2 = ecc*se0
	f3 = ecc*ce0
	f4 = -f2
	u1 = -f/f1
	u2 = -f/(f1+0.50*f2*u1)
	u3 = -f/(f1+0.50*f2*u2+.16666666666667*f3*u2*u2)
	u4 = -f/(f1+0.50*f2*u3+.16666666666667*f3*u3*u3+.041666666666667*f4*u3**3)
	
	eccanom=e0+u4
	
	for j in range(0,len(m)):
		while eccanom[j]>=2.0*np.pi:
			eccanom[j]=eccanom[j]-2.0*np.pi
		while eccanom[j]<2.0*np.pi:
			eccanom[j]=eccanom[j]+2.0*np.pi
	##better solution
	#print("ecc anomaly before iteration inside kepler equation :", eccanom)

	CONT=True
	thresh=10**-3
	for j in range(0,len(m)):
		if m[j]<0:
			m[j]=m[j]+2.0*np.pi
	diff=eccanom-np.sin(eccanom)-m
	for j in range(0,len(m)):
		if abs(diff[j])>10**-10:
			I=diff[j]
			while CONT==True:
				fe=eccanom[j]-ecc*np.sin(eccanom[j])-m[j]
				fs=1.0-ecc*np.cos(eccanom[j])
				oldval=eccanom[j]
				eccanom[j]=oldval-fe/fs
				if abs(oldval-eccanom[j])<thresh :CONT=False
			while eccanom[j]>= np.pi:eccanom[j]=eccanom[j]-2.0*np.pi
			while eccanom[j]< np.pi:eccanom[j]=eccanom[j]+2.0*np.pi

	# Iterate until convergence for each m value
	thresh = 1e-6  # Convergence threshold
	for j in range(len(m)):
        # Iterative correction (Newton-Raphson method)
		max_iter = 40  # Maximum number of iterations for each eccentric anomaly
		iter_count = 0
		
		while iter_count < max_iter:
            # Calculate the difference (Kepler's equation)
			fe = eccanom[j] - ecc * np.sin(eccanom[j]) - m[j]
			fs = 1.0 - ecc * np.cos(eccanom[j])

			# If fs is too small, break out to avoid division by zero
			if abs(fs) < 1e-10:
				break

			# Update the Eccentric Anomaly using Newton-Raphson
			new_eccanom = eccanom[j] - fe / fs

			# Check for convergence
			if abs(new_eccanom - eccanom[j]) < thresh:
				eccanom[j] = new_eccanom
				break
			eccanom[j] = new_eccanom
			iter_count += 1

        # If maximum iterations are exceeded, print a warning
		if iter_count >= max_iter:
			print(f"Warning: Did not converge for m[{j}] after {max_iter} iterations.")

		# Ensure the final value is within [-pi, pi]
		while eccanom[j] >= np.pi:
			eccanom[j] -= 2 * np.pi
		while eccanom[j] < -np.pi:
			eccanom[j] += 2 * np.pi
	return eccanom

# %%
## Function to find event files/lc files from the directory 
def find_event_files(base_directory):
    event_files = []
    
    # Regular expression to match the pattern ObsID/xti/event_cl/
    obsid_pattern = re.compile(r'^\d{10}$')
    #obsid_pattern = re.compile(r'^\d{10}/xti/event_cl/$')
    #For one file
    #obsid_pattern = re.compile(r'6050390244/xti/event_cl/$')
    
    # Regular expressions to match the specific filename patterns
    file_pattern = re.compile(r'^ni\d{10}_0mpu7_cl_(night|daynotconsidered)_barycorr.evt$')
    #file_pattern = re.compile(r'^ni\d{10}_cl_(night|day)mpu7_sr_night_barycorr.lc$')


    for obsid_dir in os.listdir(base_directory):
        obsid_path = os.path.join(base_directory, obsid_dir)

        # Check if it's a directory and matches the 10-digit ObsID pattern
        if os.path.isdir(obsid_path) and obsid_pattern.match(obsid_dir):
            #print(f"Found 10-digit ObsID folder: {obsid_dir}")

            # Look for files in this directory matching the .evt pattern
            for file in os.listdir(obsid_path):
                if file_pattern.match(file):
                    full_path = os.path.join(obsid_path, file)
                    event_files.append(full_path)
                    # print(f"Found .evt file: {full_path}")

    return event_files

# %%
# Method to write corrected FITS file
def write_corrected_fits(original_fits, corrected_timestamps):
    base_name = os.path.basename(original_fits)
    original_dir = os.path.dirname(original_fits)
    
    # Construct the new filename
    new_file = os.path.join(original_dir, base_name.replace('.evt', '_orbit_piexpiex.evt'))
    #new_file = os.path.join(original_dir, base_name.replace('.lc', '_orbit_piexpiex.lc'))

    try:
        # Read the original FITS file and modify the 'TIME' column
        with fits.open(original_fits, mode='readonly') as hdul:
            # Extract necessary values from the header
            MJDREFI = hdul[1].header['MJDREFI']
            MJDREFF = hdul[1].header['MJDREFF']
            TIMEZERO = hdul[1].header['TIMEZERO']

            # Combine MJDREFI and MJDREFF to get the full MJDREF
            MJDREF = MJDREFI + MJDREFF

            # Convert the MJD timestamps to MET using the formula
            corrected_met = (corrected_timestamps - MJDREF) * 86400 - TIMEZERO

            hdul[1].data['TIME'] = corrected_met
            hdul.writeto(new_file, overwrite=True)
        
        print(f"Corrected FITS file saved as {new_file}")
    
    except Exception as e:
        print(f"Error saving corrected FITS file: {str(e)}")

# %%
# Main function to process event files and save corrected fits files

def process_event_files(base_directory, asini, porb, ecc, omega_d, t0, t90):
    event_files = find_event_files(base_directory)
    
    all_input_times = []
    all_corrected_times = []

    for event_file in event_files:
        with fits.open(event_file) as evt:
            # Extract input times
            met = evt[1].data['BARYTIME'] ##Use this when evt while with Barytime=Yes is used. 
            #met = evt[1].data['TIME'] ## Use this on barycorr lc or evt files where Barytime=No
            # Check if BARYTIME is empty, skip if so
            if len(met) == 0:
                print(f"Skipping file {event_file}: No time values found.")
                continue

            times = ((met+evt[1].header['TIMEZERO']) / 86400) + evt[1].header['MJDREFI'] + evt[1].header['MJDREFF']
            all_input_times.append(times)

            # Correct the times using your Binary_orbit function
            corrected_times = Binary_orbit(times, asini, porb, ecc, omega_d, t90)
            all_corrected_times.append(corrected_times)

            print("Romer Delay: ",(corrected_times-times)*86400)
            # Save the corrected FITS file
            write_corrected_fits(event_file, corrected_times)
    return all_input_times, all_corrected_times

# %%
############
# Input parameters taken from: 
# https://gammaray.nsstc.nasa.gov/gbm/science/pulsars/lightcurves/swiftj0243.html
############

base_directory = "./reduced_output" #Change the data accordingly\
asini = 115.531  # in light-seconds
porb = 27.6943  # convert days to seconds
ecc = 0.1029
omega_d = -74.05
t0=0
t90 = 58116.097  # Modified Julian Date

# Run the processing
input_times, corrected_times=process_event_files(base_directory, asini, porb, ecc, omega_d,t0, t90)
# Out:
# starting iterations (max 20)
# Mean Anomaly: [1.95079148 1.95079149 1.95079149 ... 2.12836133 2.12836133 2.12836133]
# Eccentric Anomaly: [2.04245637 2.04245637 2.04245638 ... 2.21089115 2.21089115 2.21089116]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.95055511 1.95055512 1.95055512 ... 2.12809063 2.12809063 2.12809064]
# Eccentric Anomaly: [2.04223055 2.04223056 2.04223056 ... 2.21063613 2.21063613 2.21063613]
# iteration 2 completed (max 20)
# Romer Delay:  [ -90.01502926  -90.01502988  -90.01502988 ... -103.08718665 -103.08718665
#  -103.08718728]
# Corrected FITS file saved as ./reduced_output/6050390261/ni6050390261_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [0.14745859 0.14745872 0.14745874 ... 0.16246123 0.16246137 0.16246144]
# Eccentric Anomaly: [0.16428787 0.16428802 0.16428803 ... 0.18098287 0.18098302 0.1809831 ]
# iteration 1 completed (max 20)
# Mean Anomaly: [0.14770275 0.14770288 0.14770289 ... 0.16270318 0.16270332 0.16270339]
# Eccentric Anomaly: [0.16455961 0.16455975 0.16455977 ... 0.18125207 0.18125222 0.1812523 ]
# iteration 2 completed (max 20)
# Romer Delay:  [92.97889557 92.97888803 92.9788874  ... 92.14061431 92.14060677
#  92.14060237]
# Corrected FITS file saved as ./reduced_output/6050390212/ni6050390212_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [-2.76561361 -2.7656136  -2.7656136  ... -2.73480272 -2.73480272
#  -2.73480272]
# Eccentric Anomaly: [-2.80007647 -2.80007647 -2.80007647 ... -2.77197616 -2.77197616
#  -2.77197615]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.76589074 -2.76589074 -2.76589073 ... -2.73507482 -2.73507482
#  -2.73507482]
# Eccentric Anomaly: [-2.80032911 -2.80032911 -2.8003291  ... -2.77222443 -2.77222443
#  -2.77222443]
# iteration 2 completed (max 20)
# Romer Delay:  [-105.53898385 -105.53898385 -105.53898322 ... -103.62087353 -103.62087353
#  -103.6208729 ]
# Corrected FITS file saved as ./reduced_output/6050390240/ni6050390240_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [1.46684229 1.46684229 1.46684229 ... 1.57177098 1.57177098 1.57177099]
# Eccentric Anomaly: [1.56974223 1.56974223 1.56974224 ... 1.67412218 1.67412218 1.67412218]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.46672969 1.46672969 1.4667297  ... 1.57162844 1.57162844 1.57162844]
# Eccentric Anomaly: [1.56962962 1.56962962 1.56962963 ... 1.67398113 1.67398113 1.67398114]
# iteration 2 completed (max 20)
# Romer Delay:  [-42.88005244 -42.88005244 -42.88005307 ... -54.28348775 -54.28348775
#  -54.28348838]
# Corrected FITS file saved as ./reduced_output/6050390251/ni6050390251_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [1
0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [ 3.06964332  3.06964448  3.06964481 ... -3.05220694 -3.05220692
#  -3.05220686]
# Eccentric Anomaly: [ 3.07635184  3.07635289  3.07635319 ... -3.06053831 -3.06053828
#  -3.06053823]
# iteration 1 completed (max 20)
# Mean Anomaly: [ 3.06931681  3.06931797  3.06931829 ... -3.05252101 -3.05252098
#  -3.05252093]
# Eccentric Anomaly: [ 3.07605573  3.07605678  3.07605708 ... -3.06082316 -3.06082313
#  -3.06082308]
# iteration 2 completed (max 20)
# Romer Delay:  [-124.34339302 -124.34336788 -124.34336033 ... -119.60373607 -119.60373544
#  -119.60373293]
# Corrected FITS file saved as ./reduced_output/6050390225/ni6050390225_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [-2.50044209 -2.50044208 -2.50044208 ... -2.42673608 -2.42673608
#  -2.42673607]
# Eccentric Anomaly: [-2.5572104  -2.55721039 -2.55721039 ... -2.48920516 -2.48920516
#  -2.48920515]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.50066969 -2.50066969 -2.50066969 ... -2.42694759 -2.42694759
#  -2.42694758]
# Eccentric Anomaly: [-2.55742001 -2.55742001 -2.55742001 ... -2.48940068 -2.48940068
#  -2.48940068]
# iteration 2 completed (max 20)
# Romer Delay:  [-86.67642397 -86.67642397 -86.67642397 ... -80.54812602 -80.54812602
#  -80.54812539]
# Corrected FITS file saved as ./reduced_output/6050390267/ni6050390267_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [1.8774941  1.87749412 1.87749412 ... 1.98171419 1.9817143  1.98171441]
# Eccentric Anomaly: [1.97221436 1.97221438 1.97221438 ... 2.07195996 2.07196007 2.07196018]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.87727384 1.87727386 1.87727386 ... 1.98147135 1.98147146 1.98147158]
# Eccentric Anomaly: [1.97200261 1.97200263 1.97200263 ... 2.07172857 2.07172867 2.07172878]
# iteration 2 completed (max 20)
# Romer Delay:  [-83.88324108 -83.88324296 -83.88324296 ... -92.47671752 -92.47672632
#  -92.47673512]
# Corrected FITS file saved as ./reduced_output/6050390282/ni6050390282_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [-3.05910001 -3.0591     -3.05909996 ... -3.05723811 -3.05723809
#  -3.05723809]
# Eccentric Anomaly: [-3.06679002 -3.06679001 -3.06678998 ... -3.06510138 -3.06510137
#  -3.06510137]
# iteration 1 completed (max 20)
# Mean Anomaly: [-3.05941473 -3.05941472 -3.05941469 ... -3.05755265 -3.05755264
#  -3.05755264]
# Eccentric Anomaly: [-3.06707546 -3.06707545 -3.06707542 ... -3.06538666 -3.06538665
#  -3.06538665]
# iteration 2 completed (max 20)
# Romer Delay:  [-119.85445451 -119.85445451 -119.85445325 ... -119.78715139 -119.78715076
#  -119.78715076]
# Corrected FITS file saved as ./reduced_output/6050390265/ni6050390265_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [1.93206449 1.93206458 1.93206465 ... 2.09317809 2.09317818 2.09317828]
# Eccentric Anomaly: [2.02455176 2.02455185 2.02455191 ... 2.17770188 2.17770196 2.17770206]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.93183213 1.93183223 1.93183229 ... 2.09291365 2.09291374 2.09291384]
# Eccentric Anomaly: [2.02432943 2.02432952 2.02432958 ... 2.1774521  2.17745218 2.17745227]
# iteration 2 completed (max 20)
# Romer Delay:  [ -88.4876556   -88.48766377  -88.4876688  ... -100.70580498 -100.70581064
#  -100.70581818]
# Corrected FITS file saved as ./reduced_output/6050390220/ni6050390220_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [0
0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [0.80879415 0.80879415 0.80879415 ... 1.01465449 1.01465449 1.01465449]
# Eccentric Anomaly: [0.88866852 0.88866852 0.88866853 ... 1.10666896 1.10666896 1.10666896]
# iteration 1 completed (max 20)
# Mean Anomaly: [0.80888363 0.80888363 0.80888364 ... 1.01468089 1.01468089 1.01468089]
# Eccentric Anomaly: [0.88876422 0.88876422 0.88876422 ... 1.10669663 1.10669664 1.10669664]
# iteration 2 completed (max 20)
# Romer Delay:  [34.07857006 34.07857006 34.07857006 ... 10.05347972 10.05347909
#  10.05347909]
# Corrected FITS file saved as ./reduced_output/6050390256/ni6050390256_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [-0.1594851  -0.159485   -0.15948496 ... -0.08478146 -0.08478141
#  -0.0847814 ]
# Eccentric Anomaly: [-0.17767146 -0.17767134 -0.1776713  ... -0.09449003 -0.09448997
#  -0.09448996]
# iteration 1 completed (max 20)
# Mean Anomaly: [-0.15921337 -0.15921326 -0.15921323 ... -0.08451328 -0.08451323
#  -0.08451322]
# Eccentric Anomaly: [-0.1773691  -0.17736899 -0.17736894 ... -0.09419123 -0.09419118
#  -0.09419116]
# iteration 2 completed (max 20)
# Romer Delay:  [103.48190388 103.48190262 103.48190262 ... 102.1304911  102.13048984
#  102.13048984]
# Corrected FITS file saved as ./reduced_output/6050390276/ni6050390276_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [2.28793438 2.28793453 2.28793455 ... 2.39218859 2.3921886  2.39218863]
# Eccentric Anomaly: [2.36038977 2.36038991 2.36038993 ... 2.45723912 2.45723913 2.45723916]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.28763889 2.28763904 2.28763906 ... 2.39188018 2.39188019 2.39188022]
# Eccentric Anomaly: [2.36011441 2.36011455 2.36011456 ... 2.45695348 2.45695349 2.45695351]
# iteration 2 completed (max 20)
# Romer Delay:  [-112.52766866 -112.52767683 -112.52767746 ... -117.45130986 -117.45131048
#  -117.45131174]
# Corrected FITS file saved as ./reduced_output/6050390284/ni6050390284_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [1.49912662 1.49912662 1.49912662 ... 1.55833191 1.55833191 1.55833191]
# Eccentric Anomaly: [1.6019766  1.6019766  1.6019766  ... 1.66081527 1.66081527 1.66081527]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.49900466 1.49900466 1.49900466 ... 1.55819312 1.55819312 1.55819312]
# Eccentric Anomaly: [1.60185504 1.60185504 1.60185504 ... 1.66067775 1.66067775 1.66067775]
# iteration 2 completed (max 20)
# Romer Delay:  [-46.44399346 -46.44399346 -46.44399346 ... -52.85308727 -52.85308727
#  -52.85308727]
# Corrected FITS file saved as ./reduced_output/6050390231/ni6050390231_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [0.82552004 0.82552005 0.82552005 ... 0.88495098 0.88495098 0.88495098]
# Eccentric Anomaly: [0.90654104 0.90654105 0.90654105 ... 0.96982132 0.96982132 0.96982133]
# iteration 1 completed (max 20)
# Mean Anomaly: [0.82560453 0.82560454 0.82560454 ... 0.88501748 0.88501748 0.88501749]
# Eccentric Anomaly: [0.90663125 0.90663126 0.90663126 ... 0.96989194 0.96989194 0.96989194]
# iteration 2 completed (max 20)
# Romer Delay:  [32.17500276 32.17500213 32.1750015  ... 25.32744762 25.32744699
#  25.32744699]
# Corrected FITS file saved as ./reduced_output/6050390228/ni6050390228_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [0.67707047 0.67707047 0.67707047 ... 0.79485236 0.79485237 0.79485237]
# Eccentric Anomaly: [0.74698368 0.74698368 0.74698368 ... 0.87375008 0.87375009 0.87375009]
# iteration 1 completed (max 20)
# Mean Anomaly: [0

# iteration 1 completed (max 20)
# Mean Anomaly: [1.07278028 1.07278029 1.07278029 ... 1.24918666 1.24918667 1.24918667]
# Eccentric Anomaly: [1.16742169 1.1674217  1.16742171 ... 1.3495791  1.34957911 1.34957911]
# iteration 2 completed (max 20)
# Romer Delay:  [  3.12771136   3.1277101    3.1277101  ... -17.86652701 -17.86652827
#  -17.86652827]
# Corrected FITS file saved as ./reduced_output/6050390257/ni6050390257_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [2.80503312 2.8050335  2.80503352 ... 2.81100136 2.81100136 2.81100136]
# Eccentric Anomaly: [2.83599221 2.83599256 2.83599258 ... 2.8414267  2.8414267  2.84142671]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.80469998 2.80470036 2.80470038 ... 2.81066818 2.81066818 2.81066818]
# Eccentric Anomaly: [2.83568884 2.83568919 2.83568921 ... 2.84112334 2.84112334 2.84112334]
# iteration 2 completed (max 20)
# Romer Delay:  [-126.86695796 -126.86695922 -126.86695922 ... -126.88340577 -126.88340577
#  -126.88340577]
# Corrected FITS file saved as ./reduced_output/6050390224/ni6050390224_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [2.71296402 2.71296402 2.71296402 ... 2.91930139 2.91930139 2.91930139]
# Eccentric Anomaly: [2.75204258 2.75204258 2.75204259 ... 2.93991375 2.93991375 2.93991375]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.71263269 2.71263269 2.71263269 ... 2.91896898 2.91896898 2.91896898]
# Eccentric Anomaly: [2.75174005 2.75174005 2.75174005 ... 2.93961178 2.93961178 2.93961178]
# iteration 2 completed (max 20)
# Romer Delay:  [-126.18036065 -126.18036065 -126.18036065 ... -126.59065754 -126.59065754
#  -126.59065691]
# Corrected FITS file saved as ./reduced_output/6050390237/ni6050390237_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [1.55672828 1.55672828 1.55672828 ... 1.64487503 1.64487503 1.64487503]
# Eccentric Anomaly: [1.65922621 1.65922622 1.65922622 ... 1.74619622 1.74619622 1.74619622]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.55658995 1.55658995 1.55658995 ... 1.6447125  1.64471251 1.64471251]
# Eccentric Anomaly: [1.65908912 1.65908912 1.65908912 ... 1.74603656 1.74603656 1.74603656]
# iteration 2 completed (max 20)
# Romer Delay:  [-52.68178023 -52.68178023 -52.68178023 ... -61.8928089  -61.89280953
#  -61.89280953]
# Corrected FITS file saved as ./reduced_output/6050390259/ni6050390259_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [0.88093716 0.88093788 0.88093796 ... 0.94050372 0.94050374 0.94050387]
# Eccentric Anomaly: [0.96555872 0.96555948 0.96555957 ... 1.02864809 1.02864811 1.02864825]
# iteration 1 completed (max 20)
# Mean Anomaly: [0.88100489 0.88100561 0.88100569 ... 0.94055317 0.94055318 0.94055332]
# Eccentric Anomaly: [0.96563066 0.96563142 0.96563151 ... 1.02870031 1.02870033 1.02870047]
# iteration 2 completed (max 20)
# Romer Delay:  [25.79363147 25.79354849 25.79353843 ... 18.82934743 18.82934554
#  18.82932982]
# Corrected FITS file saved as ./reduced_output/6050390280/ni6050390280_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [-2.59005428 -2.59005424 -2.59005423 ... -2.58774593 -2.58774592
#  -2.58774592]
# Eccentric Anomaly: [-2.63956974 -2.6395697  -2.6395697  ... -2.63745228 -2.63745228
#  -2.63745228]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59030014 -2.5903001  -2.59030009 ... -2.58799133 -2.58799133
#  -2.58799133]
# Eccentric Anomaly: [-2.63979526 -2.63979522 -2.63979521 ... -2.6376774  -2.6376774
#  -2.6376774 ]
# iteration 2 completed (max 20)
# Romer Delay:  [-93.62966653 -93.62966276 -93.62966213 ... -93.45768685 -93.45768685
#  -93.45768685]
# Corrected FITS file saved as ./reduced_output/6050390266/ni6050390266_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [2.23501475 2.23501516 2.23501526 ... 2.23582072 2.23582075 2.23582077]
# Eccentric Anomaly: [2.31098975 2.31099013 2.31099022 ... 2.31174339 2.31174342 2.31174344]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.23472683 2.23472724 2.23472733 ... 2.23553268 2.2355327  2.23553273]
# Eccentric Anomaly: [2.31072051 2.31072088 2.31072098 ... 2.31147405 2.31147408 2.3114741 ]
# iteration 2 completed (max 20)
# Romer Delay:  [-109.64822215 -109.64824541 -109.64825107 ... -109.69396911 -109.69397037
#  -109.69397163]
# Corrected FITS file saved as ./reduced_output/6050390221/ni6050390221_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [-1.8270958  -1.82709577 -1.82709576 ... -1.70944777 -1.70944777
#  -1.70944775]
# Eccentric Anomaly: [-1.92365595 -1.92365593 -1.92365592 ... -1.80943173 -1.80943173
#  -1.80943171]
# iteration 1 completed (max 20)
# Mean Anomaly: [-1.82714882 -1.82714879 -1.82714878 ... -1.70946617 -1.70946616
#  -1.70946614]
# Eccentric Anomaly: [-1.92370715 -1.92370713 -1.92370712 ... -1.80944969 -1.80944969
#  -1.80944967]
# iteration 2 completed (max 20)
# Romer Delay:  [-20.19125854 -20.19125603 -20.19125477 ...  -7.00576629  -7.00576566
#   -7.00576315]
# Corrected FITS file saved as ./reduced_output/6050390270/ni6050390270_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# Skipping file ./reduced_output/6050390274/ni6050390274_0mpu7_cl_night_barycorr.evt: No time values found.
# starting iterations (max 20)
# Mean Anomaly: [2.47797572 2.47797572 2.47797573 ... 2.47992954 2.47992954 2.47992955]
# Eccentric Anomaly: [2.53650846 2.53650847 2.53650847 ... 2.53830975 2.53830975 2.53830975]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.47765866 2.47765866 2.47765867 ... 2.47961231 2.47961231 2.47961231]
# Eccentric Anomaly: [2.53621614 2.53621614 2.53621615 ... 2.53801729 2.53801729 2.5380173 ]
# iteration 2 completed (max 20)
# Romer Delay:  [-120.74373253 -120.74373253 -120.74373253 ... -120.81064275 -120.81064275
#  -120.81064275]
# Corrected FITS file saved as ./reduced_output/6050390263/ni6050390263_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [0.57416042 0.57416042 0.57416043 ... 0.66334314 0.66334314 0.66334314]
# Eccentric Anomaly: [0.63521631 0.63521631 0.63521631 ... 0.73212696 0.73212696 0.73212696]
# iteration 1 completed (max 20)
# Mean Anomaly: [0.57431596 0.57431596 0.57431596 ... 0.6634746  0.6634746  0.6634746 ]
# Eccentric Anomaly: [0.63538589 0.63538589 0.63538589 ... 0.73226932 0.73226932 0.73226932]
# iteration 2 completed (max 20)
# Romer Delay:  [59.23221179 59.23221179 59.23221116 ... 50.06506112 50.06506112
#  50.06506112]
# Corrected FITS file saved as ./reduced_output/6050390247/ni6050390247_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [1.9805566  1.9805566  1.98055661 ... 2.03957432 2.03957432 2.03957432]
# Eccentric Anomaly: [2.07085686 2.07085686 2.07085686 ... 2.12696561 2.12696562 2.12696562]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.980314   1.98031401 1.98031401 ... 2.03931993 2.03931994 2.03931994]
# Eccentric Anomaly: [2.07062567 2.07062567 2.07062567 ... 2.12672433 2.12672434 2.12672434]
# iteration 2 completed (max 20)
# Romer Delay:  [-92.38593334 -92.38593397 -92.38593397 ... -96.87636991 -96.87637053
#  -96.87637053]
# Corrected FITS file saved as ./reduced_output/6050390253/ni6050390253_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [2.42507428 2.42507512 2.42507546 ... 2.54316441 2.54316495 2.54316718]
# Eccentric Anomaly: [2.4876689  2.48766968 2.48766999 ... 2.59651635 2.59651684 2.59651889]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.42476234 2.42476318 2.42476351 ... 2.542842   2.54284254 2.54284477]
# Eccentric Anomaly: [2.48738051 2.48738129 2.4873816  ... 2.59622001 2.59622051 2.59622256]
# iteration 2 completed (max 20)
# Romer Delay:  [-118.79514121 -118.79517452 -118.79518772 ... -122.78063432 -122.78064941
#  -122.78071227]
# Corrected FITS file saved as ./reduced_output/6050390222/ni6050390222_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [0.89867691 0.89867691 0.89867692 ... 1.08991321 1.08991321 1.08991321]
# Eccentric Anomaly: [0.98438564 0.98438564 0.98438565 ... 1.18526003 1.18526003 1.18526003]
# iteration 1 completed (max 20)
# Mean Anomaly: [0.89873922 0.89873922 0.89873923 ... 1.08991605 1.08991605 1.08991605]
# Eccentric Anomaly: [0.98445171 0.98445171 0.98445173 ... 1.18526299 1.18526299 1.18526299]
# iteration 2 completed (max 20)
# Romer Delay:  [23.72962197 23.72962134 23.72962008 ...  1.08154148  1.08154148
#   1.08154148]
# Corrected FITS file saved as ./reduced_output/6050390229/ni6050390229_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [1.31889102 1.31889102 1.31889102 ... 1.31903018 1.31903018 1.31903018]
# Eccentric Anomaly: [1.42063305 1.42063305 1.42063305 ... 1.42077438 1.42077438 1.42077439]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.31882267 1.31882267 1.31882268 ... 1.31896179 1.31896179 1.31896179]
# Eccentric Anomaly: [1.42056363 1.42056364 1.42056364 ... 1.42070492 1.42070493 1.42070493]
# iteration 2 completed (max 20)
# Romer Delay:  [-26.02834152 -26.02834215 -26.02834215 ... -26.04452719 -26.04452781
#  -26.04452844]
# Corrected FITS file saved as ./reduced_output/6050390217/ni6050390217_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [-0.73132443 -0.73132443 -0.73132443 ... -0.68676873 -0.68676872
#  -0.68676872]
# Eccentric Anomaly: [-0.80553614 -0.80553613 -0.80553613 ... -0.7574698  -0.75746979
#  -0.75746979]
# iteration 1 completed (max 20)
# Mean Anomaly: [-0.73109255 -0.73109254 -0.73109254 ... -0.68652979 -0.68652979
#  -0.68652979]
# Eccentric Anomaly: [-0.80528644 -0.80528644 -0.80528644 ... -0.75721156 -0.75721155
#  -0.75721155]
# iteration 2 completed (max 20)
# Romer Delay:  [88.30918455 88.30918518 88.30918518 ... 90.99144847 90.99144847
#  90.99144847]
# Corrected FITS file saved as ./reduced_output/6050390246/ni6050390246_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [-2.03190589 -2.03190584 -2.03190582 ... -1.91437866 -1.91437865
#  -1.91437865]
# Eccentric Anomaly: [-2.1196901  -2.11969006 -2.11969004 ... -2.00761651 -2.0076165
#  -2.0076165 ]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.03201738 -2.03201733 -2.03201731 ... -1.91445696 -1.91445696
#  -1.91445696]
# Eccentric Anomaly: [-2.11979592 -2.11979587 -2.11979585 ... -2.00769154 -2.00769154
#  -2.00769154]
# iteration 2 completed (max 20)
# Romer Delay:  [-42.45895988 -42.45895485 -42.45895233 ... -29.81998762 -29.81998699
#  -29.81998636]
# Corrected FITS file saved as ./reduced_output/6050390269/ni6050390269_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [-2.93646283 -2.93646282 -2.93646282 ... -2.93516317 -2.93516317
#  -2.93516305]
# Eccentric Anomaly: [-2.9555013  -2.95550129 -2.95550129 ... -2.95432099 -2.95432099
#  -2.95432087]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.93676419 -2.93676418 -2.93676418 ... -2.93546438 -2.93546438
#  -2.93546425]
# Eccentric Anomaly: [-2.95577499 -2.95577498 -2.95577498 ... -2.95459454 -2.95459454
#  -2.95459442]
# iteration 2 completed (max 20)
# Romer Delay:  [-114.76723545 -114.76723545 -114.76723482 ... -114.70630174 -114.70630174
#  -114.70629545]
# Corrected FITS file saved as ./reduced_output/6050390226/ni6050390226_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
# starting iterations (max 20)
# Mean Anomaly: [2.65478404 2.65478404 2.65478405 ... 2.83145315 2.83145316 2.83145316]
# Eccentric Anomaly: [2.69886682 2.69886682 2.69886683 ... 2.86004332 2.86004334 2.86004334]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.65445494 2.65445495 2.65445495 ... 2.83111988 2.8311199  2.8311199 ]
# Eccentric Anomaly: [2.69856572 2.69856572 2.69856573 ... 2.85974004 2.85974005 2.85974005]
# iteration 2 completed (max 20)
# Romer Delay:  [-125.32681783 -125.32681783 -125.32681783 ... -126.91389872 -126.91389872
#  -126.91389872]
# Corrected FITS file saved as ./reduced_output/6050390264/ni6050390264_0mpu7_cl_night_barycorr_orbit_piexpiex.evt

# %%
input_times_flat = np.concatenate(input_times)
corrected_times_flat = np.concatenate(corrected_times)

# %%
np.savez("lc_corrected_time_piexpiex.npz", input_times=input_times_flat, corrected_times=corrected_times_flat)
print(f"Times saved successfully")
# Out:
# Times saved successfully

# %%
delays=(input_times_flat-corrected_times_flat)*86400.

# %%
delays
# Out:
# array([ 89.99332411,  89.99332599,  89.99332788, ..., 126.91382265,
#        126.91382265, 126.91382265])

# %% [markdown]
# ## Plotting all the delays

# %%
import numpy as np
import matplotlib.pyplot as plt
data=np.load("evt_corrected_time_piexpiex.npz")

# %%
input=np.sort(data['input_times'])
corrected=np.sort(data['corrected_times'])

# %%
input
# Out:
# array([60045.60321999, 60045.60322032, 60045.60322036, ...,
#        60203.71351316, 60203.71351321, 60203.71351334])

# %%
delay= (corrected-input)*86400

# %%
plt.scatter(input[::200],(delay)[::200])

# %%
# # Orbital parameters provided TEST
# a_sin_i = 115.531  # Semi-major axis in light-seconds
# P_orb = 27.6943  # Orbital period in days
# e = 0.1029  # Eccentricity
# omega = -74.05  # Longitude of periastron in degree
# T_pi2 = 58116.097  # T_pi/2 in seconds 

# evt=fits.open('./reduced_output/6050390248/ni6050390248_0mpu7_cl_night_barycorr_orbit.evt')
# met=evt[1].data['BARYTIME']
# times=(met/86400)+evt[1].header['MJDREFI'] +evt[1].header['MJDREFF']
# print(times)
#TIME=Binary_orbit(time=times,asini=a_sin_i,ecc=e,porb=P_orb,omega_d=omega,t90=T_pi2)
# Out:
# [60141.27605931 60141.27605932 60141.27605933 ... 60141.87021361
#  60141.87021362 60141.87021363]
