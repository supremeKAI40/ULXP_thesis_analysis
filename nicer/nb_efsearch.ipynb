# %%
import os
import subprocess
import numpy as np
from astropy.io import fits

# %%
# File to store the consolidated results for all light curves
consolidated_file = "all_lc_periods_evt_files_bary_orbit.txt"

# Create or clear the consolidated file
with open(consolidated_file, "w") as f:
    f.write("LC_File_Path\tPeriod\tChi-square\tTSTARTI\n")

# Find all obsID folders in the "output" directory
obsid_folders = [f.path for f in os.scandir("./reduced_output") if f.is_dir() and f.name.startswith("6050")]

# Loop through each obsID folder
for obsid_folder in obsid_folders:
    obsid = os.path.basename(obsid_folder)
    print(f"Processing obsID: {obsid}")

    # Define the light curve file path
    lc_files = []
    for root, dirs, files in os.walk(obsid_folder):
        for file in files:
            if file.endswith("cl_night_barycorr_orbit_piexpiex.evt"):
                lc_files.append(os.path.join(root, file))

    # Check if any light curve files were found
    if not lc_files:
        print(f"No light curve files found for obsID: {obsid}")
        continue

    # Loop through each light curve file
    for lc_file in lc_files:
        print(f"Processing light curve: {lc_file}")
        
        # Define paths for output files
        lc_folder = os.path.dirname(lc_file)
        output_folder = os.path.join(lc_folder, "efsearch_output")
        os.makedirs(output_folder, exist_ok=True)
        output_fits = os.path.join(output_folder, "testing_efsearch.fes")

        # Construct the efsearch command
        efsearch_cmd = f'efsearch {lc_file} window=- sepoch=INDEF dper=9.80 nphase=64 nbint=INDEF dres=1e-5 nper=1024 plot=no outfile={output_fits}'

        try:
            # Run the efsearch command
            subprocess.run(efsearch_cmd, shell=True, check=True)

            # Open the .fes FITS file and extract the best-fit period
            with fits.open(output_fits) as efsearch_fits:
                # Extract data from the 'RESULTS' table
                results_data = efsearch_fits['RESULTS'].data
                max_chisq_index = np.argmax(results_data['CHISQRD1'])  # Get index of maximum chi-square
                best_fit_period = results_data['PERIOD'][max_chisq_index]
                chisq_max = results_data['CHISQRD1'][max_chisq_index]

                # Extract the observation start time (TSTARTI) from the FITS header
                tstarti = efsearch_fits['RESULTS'].header.get('TSTARTI', 'N/A')  # 'N/A' if the keyword is missing

            # Append the results to the consolidated file
            with open(consolidated_file, "a") as f_out:
                f_out.write(f"{obsid}\t{best_fit_period}\t{chisq_max}\t{tstarti}\n")
            print(f"Processed {lc_file}, Best-fit period: {best_fit_period}, Chi-square: {chisq_max}, TSTARTI: {tstarti}")

        except subprocess.CalledProcessError as e:
            print(f"Error processing {lc_file}: {e}")

print(f"All periods, chi-squares, and TSTARTI values saved to {consolidated_file}")
# Out:
# Processing obsID: 6050390261
# Processing light curve: ./reduced_output/6050390261/ni6050390261_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390261/ni6050390261_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20174 01:46:47.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20174 20:33:45.184
#  No. of Rows .......      1013196        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20174 01:46:47.184
#  No. of Rows .......            3        Last GTI Stop ..... 20174 20:33:45.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20174.07415722222  (days)       1:46:47:184  (h:m:s:ms)
#  Expected Stop .... 20174.85677296296  (days)      20:33:45:184  (h:m:s:ms)
#
#  Default Epoch is:  20174.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6899.80
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            441587
#
#  Default Newbins per Interval are:      441587
#  (giving       1 Interval of       441587 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       441587 Newbins of      0.153125     (s)
#  Default resolution is 0.7101658337E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
#   Chisq. vs. period ready
#
#  Period :   9.795    dP/dt :   0.000
#  Intv    1   Start 
184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20117.01987481481  (days)       0:28:37:184  (h:m:s:ms)
#  Expected Stop .... 20117.99119425926  (days)      23:47:19:184  (h:m:s:ms)
#
#  Default Epoch is:  20117.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           8563.47
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            548063
#
#  Default Newbins per Interval are:      548063
#  (giving       1 Interval of       548063 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       548063 Newbins of      0.153125     (s)
#  Default resolution is 0.5721969920E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.800    dP/dt :   0.000
#  Intv    1   Start 20117  0:28:36
#      Ser.1     Avg  1098.        Chisq 0.7655E+05   Var 0.2315E+05 Newbs.     64
#                Min  937.7          Max  1352.    expVar  19.28      Bins4223399
# Writing output file: ./reduced_output/6050390232/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390232/ni6050390232_0mpu7_cl_night_barycorr_orbit_piexpiex.evt, Best-fit period: 9.80042, Chi-square: 76552.5546875, TSTARTI: 20117
# Processing obsID: 6050390273
# Processing light curve: ./reduced_output/6050390273/ni6050390273_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390273/ni6050390273_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20188 11:17:26.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20188 22:10:54.184
#  No. of Rows .......        59531        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20188 11:17:26.184
#  No. of Rows .......            5        Last GTI Stop ..... 20188 22:10:54.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20188.47044194444  (days)      11:17:26:184  (h:m:s:ms)
#  Expected Stop .... 20188.92423824074  (days)      22:10:54:184  (h:m:s:ms)
#
#  Default Epoch is:  20188.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           4000.82
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            256053
#
#  Default Newbins per Interval are:      256053
#  (giving       1 Interval of       256053 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       256053 Newbins of      0.153125     (s)
#  Default resolution is 0.1224746439E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.795    dP/dt :   0.000
#  Intv    1   Start 20188 11:17:25
# ...
# Processing obsID: 6050390222
# Processing light curve: ./reduced_output/6050390222/ni6050390222_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390222/ni6050390222_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20065 09:23:03.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20065 21:52:37.184
#  No. of Rows .......         1896        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20065 09:23:03.184
#  No. of Rows .......            2        Last GTI Stop ..... 20065 21:52:37.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20065.39100907407  (days)       9:23: 3:184  (h:m:s:ms)
#  Expected Stop .... 20065.91154148148  (days)      21:52:37:184  (h:m:s:ms)
#
#  Default Epoch is:  20065.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           4589.18
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            293708
#
#  Default Newbins per Interval are:      293708
#  (giving       1 Interval of       293708 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       293708 Newbins of      0.153125     (s)
#  Default resolution is 0.1067727130E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.803    dP/dt :   0.000
#  Intv    1   Start 20065  9:23: 2
#      Ser.1     Avg  1.518        Chisq  125.1       Var 0.2375     Newbs.     64
#                Min 0.6450          Max  2.628    expVar 0.1211      Bins   1896
# Writing output file: ./reduced_output/6050390222/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390222/ni6050390222_0mpu7_cl_night_barycorr_orbit_piexpiex.evt, Best-fit period: 9.80316, Chi-square: 125.11129760742188, TSTARTI: 20065
# Processing obsID: 6050390229
# Processing light curve: ./reduced_output/6050390229/ni6050390229_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390229/ni6050390229_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20114 01:14:15.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20114 21:28:00.184
#  No. of Rows .......      1837272        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20114 01:14:15.184
#  No. of Rows .......            6        Last GTI Stop ..... 20114 21:28:00.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20114.05156462963  (days)       1:14:15:184  (h:m:s:ms)
#  Expected Stop .... 20114.89444657407  (days)      21:28: 0:184  (h:m:s:ms)
#
#  Default Epoch is:  20114.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           7431.12
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            475592
#
#  Default Newbins per Interval are:      475592
#  (giving       1 Interval of       475592 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       475592 Newbins of      0.153125     (s)
#  Default resolution is 0.6593887197E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.801    dP/dt :   0.000
#  Intv    1   Start 20114  1:14:14
#      Ser.1     Avg  720.2        Chisq 0.2052E+05   Var  6758.     Newbs.     64
#                Min  612.2          Max  871.2    expVar  21.15      Bins1837272
# Writing output file: ./reduced_output/6050390229/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390229/ni6050390229_0mpu7_cl_night_barycorr_orbit_piexpiex.evt, Best-fit period: 9.80057, Chi-square: 20520.345703125, TSTARTI: 20114
# Processing obsID: 6050390246
# Processing light curve: ./reduced_output/6050390246/ni6050390246_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390246/ni6050390246_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20134 13:27:04.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20134 18:09:51.184
#  No. of Rows .......       802590        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20134 13:27:04.184
#  No. of Rows .......            2        Last GTI Stop ..... 20134 18:09:51.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20134.56046509259  (days)      13:27: 4:184  (h:m:s:ms)
#  Expected Stop .... 20134.75684240741  (days)      18: 9:51:184  (h:m:s:ms)
#
#  Default Epoch is:  20134.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           1731.33
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            110805
#
#  Default Newbins per Interval are:      110805
#  (giving       1 Interval of       110805 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       110805 Newbins of      0.153125     (s)
#  Default resolution is 0.2830197193E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.799    dP/dt :   0.000
#  Intv    1   Start 20134 13:27: 3
#      Ser.1     Avg  658.2        Chisq  6894.       Var  9431.     Newbs.     64
#                Min  517.0          Max  819.7    expVar  87.67      Bins 802590
# Writing output file: ./reduced_output/6050390246/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390246/ni6050390246_0mpu7_cl_night_barycorr_orbit_piexpiex.evt, Best-fit period: 9.799330000000001, Chi-square: 6893.75048828125, TSTARTI: 20134
# Processing obsID: 6050390269
# Processing light curve: ./reduced_output/6050390269/ni6050390269_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390269/ni6050390269_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20184 05:07:05.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20184 17:32:59.184
#  No. of Rows .......       103403        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20184 05:07:05.184
#  No. of Rows .......            2        Last GTI Stop ..... 20184 17:32:59.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20184.21325444444  (days)       5: 7: 5:184  (h:m:s:ms)
#  Expected Stop .... 20184.73124055555  (days)      17:32:59:184  (h:m:s:ms)
#
#  Default Epoch is:  20184.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           4566.73
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            292272
#
#  Default Newbins per Interval are:      292272
#  (giving       1 Interval of       292272 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       292272 Newbins of      0.153125     (s)
#  Default resolution is 0.1072973121E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
#   Chisq. vs. period ready
#
#  Period :   9.801    dP/dt :   0.000
#  Intv    1   Start 20184  5: 7: 4
#      Ser.1     Avg  175.2        Chisq  1742.       Var  572.4     Newbs.     64
#                Min  122.4          Max  219.2    expVar  20.52      Bins  95771
# Writing output file: ./reduced_output/6050390269/efsearch_output/testing_efsearc
# 100% completed
# Interval 2 rejected; all bins zero
#
#  Period :   9.801    dP/dt :   0.000
#  Intv    3   Start     0  0: 0: 0
#      Ser.1     Avg  0.000        Chisq  0.000       Var  0.000     Newbs.      0
#                Min 0.1000E+35      Max-0.1000E+35expVar  0.000      Bins     -1
#
# Frame ready : Writing in output : ./reduced_output/6050390269/efsearch_output/te
# Processed ./reduced_output/6050390269/ni6050390269_0mpu7_cl_night_barycorr_orbit_piexpiex.evt, Best-fit period: 9.800730000000001, Chi-square: 1742.324951171875, TSTARTI: 20184
# Processing obsID: 6050390226
# Processing light curve: ./reduced_output/6050390226/ni6050390226_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390226/ni6050390226_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20069 10:52:57.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20069 11:01:12.184
#  No. of Rows .......        16105        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20069 10:52:57.184
#  No. of Rows .......            1        Last GTI Stop ..... 20069 11:01:12.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20069.45343962963  (days)      10:52:57:184  (h:m:s:ms)
#  Expected Stop .... 20069.45916879630  (days)      11: 1:12:184  (h:m:s:ms)
#
#  Default Epoch is:  20069.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..             50.51
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.              3233
#
#  Default Newbins per Interval are:        3233
#  (giving       1 Interval of         3233 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with         3233 Newbins of      0.153125     (s)
#  Default resolution is 0.9699969069E-01
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.796    dP/dt :   0.000
#  Intv    1   Start 20069 10:52:56
#      Ser.1     Avg  17.14        Chisq  212.0       Var  7.327     Newbs.     64
#                Min  12.56          Max  23.82    expVar  2.215      Bins  16105
# Writing output file: ./reduced_output/6050390226/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390226/ni6050390226_0mpu7_cl_night_barycorr_orbit_piexpiex.evt, Best-fit period: 9.79615, Chi-square: 212.0288848876953, TSTARTI: 20069
# Processing obsID: 6050390264
# Processing light curve: ./reduced_output/6050390264/ni6050390264_0mpu7_cl_night_barycorr_orbit_piexpiex.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390264/ni6050390264_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20177 04:14:45.184
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20177 22:56:00.184
#  No. of Rows .......       251171        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20177 04:14:45.184
#  No. of Rows .......            2        Last GTI Stop ..... 20177 22:56:00.184
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20177.17691185185  (days)       4:14:45:184  (h:m:s:ms)
#  Expected Stop .... 20177.95555768519  (days)      22:56: 0:184  (h:m:s:ms)
#
#  Default Epoch is:  20177.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6864.80
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            439347
#
#  Default Newbins per Interval are:      439347
#  (giving       1 Interval of       439347 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       439347 Newbins of      0.153125     (s)
#  Default resolution is 0.7137865969E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
#   Chisq. vs. period ready
#
#  Period :   9.795    dP/dt :   0.000
#  Intv    1   Start 20177  4:14:44
#      Ser.1     Avg  371.4        Chisq  4982.       Var  3099.     Newbs.     64
#                Min  257.0          Max  444.5    expVar  39.88      Bins 221329
# Writing output file: ./reduced_output/6050390264/efsearch_output/testing_efsearc
# 100% completed
# Interval 2 rejected; all bins zero
#
#  Period :   9.795    dP/dt :   0.000
#  Intv    3   Start     0  0: 0: 0
#      Ser.1     Avg  0.000        Chisq  0.000       Var  0.000     Newbs.      0
#                Min 0.1000E+35      Max-0.1000E+35expVar  0.000      Bins     -1
#
# Frame ready : Writing in output : ./reduced_output/6050390264/efsearch_output/te
# Processed ./reduced_output/6050390264/ni6050390264_0mpu7_cl_night_barycorr_orbit_piexpiex.evt, Best-fit period: 9.795440000000001, Chi-square: 4982.13818359375, TSTARTI: 20177
# All periods, chi-squares, and TSTARTI values saved to all_lc_periods_evt_files_bary_orbit.txt
