# %%
import os
import subprocess
import numpy as np
from astropy.io import fits

# %%
# File to store the consolidated results for all light curves
consolidated_file = "all_lc_periods_chisq.txt"

# Create or clear the consolidated file
with open(consolidated_file, "w") as f:
    f.write("LC_File_Path\tPeriod\tChi-square\tTSTARTI\n")

# Find all obsID folders in the "output" directory
obsid_folders = [f.path for f in os.scandir("./reduced_output") if f.is_dir() and f.name.startswith("6050")]

# Loop through each obsID folder
for obsid_folder in obsid_folders:
    obsid = os.path.basename(obsid_folder)
    print(f"Processing obsID: {obsid}")

    # Define the light curve file path
    lc_files = []
    for root, dirs, files in os.walk(obsid_folder):
        for file in files:
            if file.endswith("night.lc"):
                lc_files.append(os.path.join(root, file))

    # Check if any light curve files were found
    if not lc_files:
        print(f"No light curve files found for obsID: {obsid}")
        continue

    # Loop through each light curve file
    for lc_file in lc_files:
        print(f"Processing light curve: {lc_file}")
        
        # Define paths for output files
        lc_folder = os.path.dirname(lc_file)
        output_folder = os.path.join(lc_folder, "efsearch_output")
        os.makedirs(output_folder, exist_ok=True)
        output_fits = os.path.join(output_folder, "testing_efsearch.fes")

        # Construct the efsearch command
        efsearch_cmd = f'efsearch {lc_file} window=- sepoch=INDEF dper=9.79 nphase=64 nbint=INDEF dres=1e-5 nper=2048 plot=no outfile={output_fits}'

        try:
            # Run the efsearch command
            subprocess.run(efsearch_cmd, shell=True, check=True)

            # Open the .fes FITS file and extract the best-fit period
            with fits.open(output_fits) as efsearch_fits:
                # Extract data from the 'RESULTS' table
                results_data = efsearch_fits['RESULTS'].data
                max_chisq_index = np.argmax(results_data['CHISQRD1'])  # Get index of maximum chi-square
                best_fit_period = results_data['PERIOD'][max_chisq_index]
                chisq_max = results_data['CHISQRD1'][max_chisq_index]

                # Extract the observation start time (TSTARTI) from the FITS header
                tstarti = efsearch_fits['RESULTS'].header.get('TSTARTI', 'N/A')  # 'N/A' if the keyword is missing

            # Append the results to the consolidated file
            with open(consolidated_file, "a") as f_out:
                f_out.write(f"{obsid}\t{best_fit_period}\t{chisq_max}\t{tstarti}\n")
            print(f"Processed {lc_file}, Best-fit period: {best_fit_period}, Chi-square: {chisq_max}, TSTARTI: {tstarti}")

        except subprocess.CalledProcessError as e:
            print(f"Error processing {lc_file}: {e}")

print(f"All periods, chi-squares, and TSTARTI values saved to {consolidated_file}")
# Out:
# Processing obsID: 6050390261
# Processing light curve: ./reduced_output/6050390261/ni6050390261_cl_night_barycorrmpu7_sr_night.lc
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390261/ni6050390261_cl_night_barycorrmp
#
#  Selected FITS extensions: 1 - RATE TABLE;
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20174 01:46:48.284
#  FITS Extension ....  1 - `RATE      `   Stop Time (d) ..... 20174 20:33:42.084
#  No. of Rows .......       197740        Bin Time (s) ......   0.1000E-01
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  2- Y-axis;  3- Y-error;  4- Fractional exposure;
#
#  File contains binned data.
#
#
#  Expected Start ... 20174.07416995370  (days)       1:46:48:284  (h:m:s:ms)
#  Expected Stop .... 20174.85673708333  (days)      20:33:42: 84  (h:m:s:ms)
#
#  Default Epoch is:  20174.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6906.41
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15296875      (s)
#  Maximum Newbin No.            442011
#
#  Default Newbins per Interval are:      442011
#  (giving       1 Interval of       442011 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       442011 Newbins of      0.152969     (s)
#  Default resolution is 0.7087606417E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     2048 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.789    dP/dt :   0.000
#  Intv    1   Start 20174  1:46:48
#      Ser.1     Avg  523.8        Chisq 0.1710E+05   Var  4706.     Newbs.     64
#                Min  395.6          Max  618.0    expVar  17.64      Bins 197740
# Writing output file: ./reduced_output/6050390261/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050
Bin Time (s) ......   0.1000E-01
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  2- Y-axis;  3- Y-error;  4- Fractional exposure;
#
#  File contains binned data.
#
#
#  Expected Start ... 20187.75802412037  (days)      18:11:33:284  (h:m:s:ms)
#  Expected Stop .... 20187.82757041667  (days)      19:51:42: 84  (h:m:s:ms)
#
#  Default Epoch is:  20187.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..            613.77
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15296875      (s)
#  Maximum Newbin No.             39282
#
#  Default Newbins per Interval are:       39282
#  (giving       1 Interval of        39282 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with        39282 Newbins of      0.152969     (s)
#  Default resolution is 0.7975154015E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     2048 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.794    dP/dt :   0.000
#  Intv    1   Start 20187 18:11:33
#      Ser.1     Avg  178.0        Chisq  2179.       Var  564.9     Newbs.     64
#                Min  135.3          Max  228.3    expVar  16.62      Bins  86960
# Writing output file: ./reduced_output/6050390272/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390272/ni6050390272_cl_night_barycorrmpu7_sr_night.lc, Best-fit period: 9.79388, Chi-square: 2179.026123046875, TSTARTI: 20187
# Processing obsID: 6050390271
# Processing light curve: ./reduced_output/6050390271/ni6050390271_cl_night_barycorrmpu7_sr_night.lc
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390271/ni6050390271_cl_night_barycorrmp
# Error processing ./reduced_output/6050390271/ni6050390271_cl_night_barycorrmpu7_sr_night.lc: Command 'efsearch ./reduced_output/6050390271/ni6050390271_cl_night_barycorrmpu7_sr_night.lc window=- sepoch=INDEF dper=9.79 nphase=64 nbint=INDEF dres=1e-5 nper=2048 plot=no outfile=./reduced_output/6050390271/efsearch_output/testing_efsearch.fes' returned non-zero exit status 1.
# Processing obsID: 6050390254
# Processing light curve: ./reduced_output/6050390254/ni6050390254_cl_night_barycorrmpu7_sr_night.lc
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390254/ni6050390254_cl_night_barycorrmp
#
#  Selected FITS extensions: 1 - RATE TABLE;
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20147 00:39:02.284
#  FITS Extension ....  1 - `RATE      `   Stop Time (d) ..... 20147 19:14:46.084
#  No. of Rows .......       188600        Bin Time (s) ......   0.1000E-01
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  2- Y-axis;  3- Y-error;  4- Fractional exposure;
#
#  File contains binned data.
#
#
#  Expected Start ... 20147.02710976852  (days)       0:39: 2:284  (h:m:s:ms)
#  Expected Stop .... 20147.80192226852  (days)      19:14:46: 84  (h:m:s:ms)
#
#  Default Epoch is:  20147.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6837.98
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15296875      (s)
#  Maximum Newbin No.            437631
#
#  Default Newbins per Interval are:      437631
#  (giving       1 Interval of       437631 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       437631 Newbins of      0.152969     (s)
#  Default resolution is 0.7158542242E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     2048 analysis results per interval
#
#   1% completed
# xrfrdhe: No data in this FITS extension
# xrcheckfiles: Couldn't process header of file:./reduced_output/6050390271/ni6050390271_cl_nigh
# xrgetparams: Error while checking out input files.
# efseah: Error reading parameters
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.792    dP/dt :   0.000
#  Intv    1   Start 20147  0:39: 2
#      Ser.1     Avg  1635.        Chisq 0.6485E+05   Var 0.5824E+05 Newbs.     64
#                Min  1249.          Max  1969.    expVar  57.75      Bins 188600
# Writing output file: ./reduced_output/6050390254/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390254/ni6050390254_cl_night_barycorrmpu7_sr_night.lc, Best-fit period: 9.79244, Chi-square: 64846.0703125, TSTARTI: 20147
# Processing obsID: 6050390279
# Processing light curve: ./reduced_output/6050390279/ni6050390279_cl_night_barycorrmpu7_sr_night.lc
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390279/ni6050390279_cl_night_barycorrmp
#
#  Selected FITS extensions: 1 - RATE TABLE;
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20195 04:14:49.284
#  FITS Extension ....  1 - `RATE      `   Stop Time (d) ..... 20195 10:34:24.084
#  No. of Rows .......       218080        Bin Time (s) ......   0.1000E-01
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  2- Y-axis;  3- Y-error;  4- Fractional exposure;
#
#  File contains binned data.
#
#
#  Expected Start ... 20195.17695930555  (days)       4:14:49:284  (h:m:s:ms)
#  Expected Stop .... 20195.44055652778  (days)      10:34:24: 84  (h:m:s:ms)
#
#  Default Epoch is:  20195.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           2326.33
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15296875      (s)
#  Maximum Newbin No.            148886
#
#  Default Newbins per Interval are:      148886
#  (giving       1 Interval of       148886 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       148886 Newbins of      0.152969     (s)
#  Default resolution is 0.2104160230E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     2048 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.790    dP/dt :   0.000
#  Intv    1   Start 20195  4:14:49
#      Ser.1     Avg  69.81        Chisq  1396.       Var  55.36     Newbs.     64
#                Min  58.34          Max  82.84    expVar  2.537      Bins 218080
# Writing output file: ./reduced_output/6050390279/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390279/ni6050390279_cl_night_barycorrmpu7_sr_night.lc, Best-fit period: 9
-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     2048 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.797    dP/dt :   0.000
#  Intv    1   Start 20117  0:28:38
#      Ser.1     Avg  1484.        Chisq 0.6125E+05   Var 0.3807E+05 Newbs.     64
#                Min  1275.          Max  1791.    expVar  39.76      Bins 358880
# Writing output file: ./reduced_output/6050390232/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390232/ni6050390232_cl_night_barycorrmpu7_sr_night.lc, Best-fit period: 9.797179999999999, Chi-square: 61249.9765625, TSTARTI: 20117
# Processing obsID: 6050390273
# Processing light curve: ./reduced_output/6050390273/ni6050390273_cl_night_barycorrmpu7_sr_night.lc
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390273/ni6050390273_cl_night_barycorrmp
#
#  Selected FITS extensions: 1 - RATE TABLE;
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20188 11:17:27.284
#  FITS Extension ....  1 - `RATE      `   Stop Time (d) ..... 20188 14:26:24.084
#  No. of Rows .......        55040        Bin Time (s) ......   0.1000E-01
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  2- Y-axis;  3- Y-error;  4- Fractional exposure;
#
#  File contains binned data.
#
#
#  Expected Start ... 20188.47045467592  (days)      11:17:27:284  (h:m:s:ms)
#  Expected Stop .... 20188.60166763889  (days)      14:26:24: 84  (h:m:s:ms)
#
#  Default Epoch is:  20188.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           1158.00
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15296875      (s)
#  Maximum Newbin No.             74112
#
#  Default Newbins per Interval are:       74112
#  (giving       1 Interval of        74112 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with        74112 Newbins of      0.152969     (s)
#  Default resolution is 0.4227115717E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     2048 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.794    dP/dt :   0.000
#  Intv    1   Start 20188 11:17:27
#      Ser.1     Avg  165.8        Chisq  906.0       Var  549.6     Newbs.     64
#                Min  127.8          Max  218.9    expVar  38.89      Bins  55040
# Writing output file: ./reduced_output/6050390273/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390273/ni6050390273_cl_night_barycorrmpu7_sr_night.lc, Best-fit period: 9.79354, Chi-square: 905.9735717773438, TSTARTI: 20188
# Processing obsID: 6050390233
# Processing light curve: ./reduced_output/6050390233/ni6050390233_cl_night_barycorrmpu7_sr_night.lc
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390233/ni6050390233_cl_night_barycorrmp
#
#  Selected FITS extensions: 1 - RATE TABLE;
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20118 02:44:59.284
#  FITS Extension ....  1 - `RATE      `   Stop Time (d) ..... 20118 23:00:36.084
#  No. of Rows .......       455200        Bin Time (s) ......   0.1000E-01
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  2- Y-axis;  3- Y-error;  4- Fractional exposure;
#
#  File contains binned data.
#
#
#  Expected Start ... 20118.11457504630  (days)       2:44:59:284  (h:m:s:ms)
#  Expected Stop .... 20118.95875097222  (days)      23: 0:36: 84  (h:m:s:ms)
#
#  Default Epoch is:  20118.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           7450.13
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15296875      (s)
#  Maximum Newbin No.            476809
#
#  Default Newbins per Interval are:      476809
#  (giving       1 Interval of       476809 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       476809 Newbins of      0.152969     (s)
#  Default resolution is 0.6570345778E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     2048 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.797    dP/dt :   0.000
#  Intv    1   Start 20118  2:44:59
#      Ser.1     Avg  1473.        Chisq 0.8605E+05   Var 0.3739E+05 Newbs.     64
#                Min  1253.          Max  1784.    expVar  27.81      Bins 455200
# Writing output file: ./reduced_output/6050390233/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390233/ni6050390233_cl_night_barycorrmpu7_sr_night.lc, Best-fit period: 9.79712, Chi-square: 86045.328125, TSTARTI: 20118
# Processing obsID: 6050390234
# Processing light curve: ./reduced_output/6050390234/ni6050390234_cl_night_barycorrmpu7_sr_night.lc
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390234/ni6050390234_cl_night_barycorrmp
#
#  Selected FITS extensions: 1 - RATE TABLE;
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20119 00:25:15.284
#  FITS Extension ....  1 - `RATE      `   Stop Time (d) ..... 20119 17:35:12.084
#  No. of Rows .......       509400        Bin Time (s) ......   0.1000E-01
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  2- Y-axis;  3- Y-error;  4- Fractional exposure;
#
#  File contains binned data.
#
#
#  Expected Start ... 20119.01753800926  (days)       0:25:15:284  (h:m:s:ms)
#  Expected Stop .... 20119.73277875000  (days)      17:35:12: 84  (h:m:s:ms)
#
#  Default Epoch is:  20119.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6312.24
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15296875      (s)
#  Maximum Newbin No.            403984
#
#  Default Newbins per Interval are:      403984
# ...
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390222/ni6050390222_cl_night_barycorrmp
#
#  Selected FITS extensions: 1 - RATE TABLE;
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20065 09:23:04.284
#  FITS Extension ....  1 - `RATE      `   Stop Time (d) ..... 20065 21:52:34.084
#  No. of Rows .......        79360        Bin Time (s) ......   0.1000E-01
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  2- Y-axis;  3- Y-error;  4- Fractional exposure;
#
#  File contains binned data.
#
#
#  Expected Start ... 20065.39102180555  (days)       9:23: 4:284  (h:m:s:ms)
#  Expected Stop .... 20065.91150560185  (days)      21:52:34: 84  (h:m:s:ms)
#
#  Default Epoch is:  20065.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           4593.44
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15296875      (s)
#  Maximum Newbin No.            293981
#
#  Default Newbins per Interval are:      293981
#  (giving       1 Interval of       293981 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       293981 Newbins of      0.152969     (s)
#  Default resolution is 0.1065647100E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     2048 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9
284
#  FITS Extension ....  1 - `RATE      `   Stop Time (d) ..... 20184 17:32:56.084
#  No. of Rows .......        53860        Bin Time (s) ......   0.1000E-01
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  2- Y-axis;  3- Y-error;  4- Fractional exposure;
#
#  File contains binned data.
#
#
#  Expected Start ... 20184.21326717592  (days)       5: 7: 6:284  (h:m:s:ms)
#  Expected Stop .... 20184.73120467593  (days)      17:32:56: 84  (h:m:s:ms)
#
#  Default Epoch is:  20184.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           4570.97
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15296875      (s)
#  Maximum Newbin No.            292543
#
#  Default Newbins per Interval are:      292543
#  (giving       1 Interval of       292543 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       292543 Newbins of      0.152969     (s)
#  Default resolution is 0.1070885306E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     2048 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.792    dP/dt :   0.000
#  Intv    1   Start 20184  5: 7: 6
#      Ser.1     Avg  237.1        Chisq  1694.       Var  945.9     Newbs.     64
#                Min  160.6          Max  298.5    expVar  35.73      Bins  53860
# Writing output file: ./reduced_output/6050390269/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390269/ni6050390269_cl_night_barycorrmpu7_sr_night.lc, Best-fit period: 9.79227, Chi-square: 1694.0726318359375, TSTARTI: 20184
# Processing obsID: 6050390226
# Processing light curve: ./reduced_output/6050390226/ni6050390226_cl_night_barycorrmpu7_sr_night.lc
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390226/ni6050390226_cl_night_barycorrmp
#
#  Selected FITS extensions: 1 - RATE TABLE;
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20069 10:52:58.284
#  FITS Extension ....  1 - `RATE      `   Stop Time (d) ..... 20069 11:01:09.084
#  No. of Rows .......        49080        Bin Time (s) ......   0.1000E-01
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  2- Y-axis;  3- Y-error;  4- Fractional exposure;
#
#  File contains binned data.
#
#
#  Expected Start ... 20069.45345236111  (days)      10:52:58:284  (h:m:s:ms)
#  Expected Stop .... 20069.45913291667  (days)      11: 1: 9: 84  (h:m:s:ms)
#
#  Default Epoch is:  20069.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..             50.13
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15296875      (s)
#  Maximum Newbin No.              3209
#
#  Default Newbins per Interval are:        3209
#  (giving       1 Interval of         3209 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with         3209 Newbins of      0.152969     (s)
#  Default resolution is 0.9762542848E-01
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     2048 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.798    dP/dt :   0.000
#  Intv    1   Start 20069 10:52:58
#      Ser.1     Avg  39.82        Chisq  356.2       Var  36.73     Newbs.     64
#                Min  28.15          Max  53.62    expVar  6.585      Bins  49080
# Writing output file: ./reduced_output/6050390226/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390226/ni6050390226_cl_night_barycorrmpu7_sr_night.lc, Best-fit period: 9.79768, Chi-square: 356.18316650390625, TSTARTI: 20069
# Processing obsID: 6050390264
# Processing light curve: ./reduced_output/6050390264/ni6050390264_cl_night_barycorrmpu7_sr_night.lc
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390264/ni6050390264_cl_night_barycorrmp
#
#  Selected FITS extensions: 1 - RATE TABLE;
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20177 04:14:46.284
#  FITS Extension ....  1 - `RATE      `   Stop Time (d) ..... 20177 22:55:57.084
#  No. of Rows .......        61860        Bin Time (s) ......   0.1000E-01
#  Right Ascension ... 40.9186             Internal time sys.. Converted to TJD
#  Declination ....... 61.4323             Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  2- Y-axis;  3- Y-error;  4- Fractional exposure;
#
#  File contains binned data.
#
#
#  Expected Start ... 20177.17692458333  (days)       4:14:46:284  (h:m:s:ms)
#  Expected Stop .... 20177.95552180555  (days)      22:55:57: 84  (h:m:s:ms)
#
#  Default Epoch is:  20177.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6871.38
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15296875      (s)
#  Maximum Newbin No.            439769
#
#  Default Newbins per Interval are:      439769
#  (giving       1 Interval of       439769 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       439769 Newbins of      0.152969     (s)
#  Default resolution is 0.7123739963E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     2048 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.793    dP/dt :   0.000
#  Intv    1   Start 20177  4:14:46
#      Ser.1     Avg  447.3        Chisq  4134.       Var  3413.     Newbs.     64
#                Min  318.8          Max  527.2    expVar  52.76      Bins  61860
# Writing output file: ./reduced_output/6050390264/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390264/ni6050390264_cl_night_barycorrmpu7_sr_night.lc, Best-fit period: 9.793289999999999, Chi-square: 4133.8466796875, TSTARTI: 20177
# All periods, chi-squares, and TSTARTI values saved to all_lc_periods_chisq.txt

# %%
print(obsid)
# Out:
# 6050390243
